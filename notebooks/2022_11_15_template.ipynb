# %% [markdown]
# # Template Demo Notebook
#
# 11/15/2022

# %%
import os, sys

# Move the path up a level to be able to index into source files
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../')
    sys.path.insert(0, 'src/')

from src import plotter as plotter
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib widget

# %% [markdown]
# # Initialize plot settings

# %%
plotter.initialize(plt)

# %% [markdown]
# # Demo data loading

# %%
df = pd.read_csv('data/raw/from-keyence/keyence_20220901_213928.csv')

# %%
df.head()
# Out:
#    computer time  Key_CH0  Key_CH1  Key_CH2  Key_CH3  Key_CH4  Key_CH5  \
# 0     1662082768      0.0      0.1      0.0      0.0      0.1      0.1
# 1     1662082773      0.0      0.1      0.0      0.0      0.1      0.1
# 2     1662082778      0.0      0.1      0.0      0.0      0.1      0.1
# 3     1662082783      0.0      0.1      0.0      0.0      0.1      0.1
# 4     1662082788      0.0      0.1      0.0      0.0      0.1      0.2
#
#    Key_CH6  Key_CH7
# 0      0.1      0.0
# 1      0.1      0.0
# 2      0.1      0.0
# 3      0.1      0.0
# 4      0.2      0.0

# %%
time_hrs = (df['computer time'] - df['computer time'][0]) / 3600
strain_um = df['Key_CH1']

# %% [markdown]
# # Demo plot

# %%
fh = plt.figure(figsize=(12, 6))

plt.plot(time_hrs, strain_um)
plt.xlabel('Test time (hrs)')
plt.ylabel('Strain (um)')
plt.grid(False)

plt.savefig('outputs/figures/fig_example.png', dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
