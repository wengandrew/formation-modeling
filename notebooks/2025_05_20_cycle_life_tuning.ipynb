# %% [markdown]
# # Tune $D_{sei}$ to get cycle life
#
# 2025/04/16
#
# The plan:
# 1. Define an objective function as some combination of expansion error and voltage error
# 1. Sweep through different values of D_sei for VC only (just start with VC for now)
# 1. Plot D_sei vs error function for the three different formation protocols
#
# Andrew Weng

# %%
import os, sys

# Move the path up a level to be able to index into source files
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../')
    sys.path.insert(0, 'src/')

from src import cellsim as cellsim

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from src import plotter as plotter
from scipy.interpolate import interp1d

# %load_ext autoreload
# %matplotlib widget

plotter.initialize(plt)

target_dir = os.getcwd()

# %% [markdown]
# # Declare Methods

# %%
def fetch_file_list(cellid):

    target_dir_arbin = f'{target_dir}/data/raw/from-voltaiq'


    if cellid == 152064:
        file_arbin_list = [
        f'{target_dir_arbin}/UMBL2022FEB_CELL152064_FORMTAP_2_P45C_5P0PSI_20220901_R1.csv',
        f'{target_dir_arbin}/UMBL2022FEB_CELL152064_FORMBASE_1_P45C_5P0PSI_20220902_R1.csv',
        f'{target_dir_arbin}/UMBL2022FEB_CELL152064_FORMAGING_1_P45C_5P0PSI_20220909_R1.csv',
        f'{target_dir_arbin}/UMBL2022FEB_CELL152064_CYC_1C1CR1_P45C_5P0PSI_20220923_R1.csv'
                        ]

        daq_channel = 'Key_CH1'

        hr_max = 20*24

    elif cellid == 152074: # BASELINE FORMATION (repeat 2)

        file_arbin_list = [
        f'{target_dir_arbin}/UMBL2022FEB_CELL152074_FORMTAP_2_P45C_5P0PSI_20220901_R1.csv',
        f'{target_dir_arbin}/UMBL2022FEB_CELL152074_FORMBASE_1_P45C_5P0PSI_20220902_R1.csv',
        f'{target_dir_arbin}/UMBL2022FEB_CELL152074_FORMAGING_1_P45C_5P0PSI_20220909_R1.csv'
                        ]

        daq_channel = 'Key_CH0'

        hr_max = 20*24

    elif cellid == 152071: # FAST FORMATION

        file_arbin_list = [
            f'{target_dir_arbin}/UMBL2022FEB_CELL152071_FORMTAP_2_P45C_5P0PSI_20220901_R1.csv',
            f'{target_dir_arbin}/UMBL2022FEB_CELL152071_FORMFAST_1_P45C_5P0PSI_20220902_R1.csv',
            f'{target_dir_arbin}/UMBL2022FEB_CELL152071_FORMAGING_1_P45C_5P0PSI_20220909_R1.csv',
            f'{target_dir_arbin}/UMBL2022FEB_CELL152071_CYC_1C1CR1_P45C_5P0PSI_20220923_R1.csv'
        ]

        daq_channel = 'Key_CH3'

        hr_max = 20*24

    elif cellid == 152098: # SUPER FAST FORMATION

        file_arbin_list = [
            f'{target_dir_arbin}/UMBL2022FEB_CELL152098_FORMTAP_2_P45C_5P0PSI_20220901_R1.csv',
            f'{target_dir_arbin}/UMBL2022FEB_CELL152098_FORMFAST_2_P45C_5P0PSI_20220902_R1.csv',
            f'{target_dir_arbin}/UMBL2022FEB_CELL152098_FORMAGING_1_P45C_5P0PSI_20220909_R1.csv',
            f'{target_dir_arbin}/UMBL2022FEB_CELL152098_CYC_1C1CR1_P45C_5P0PSI_20220923_R1.csv'
        ]

        daq_channel = 'Key_CH2'

        hr_max = 20*24


    return file_arbin_list, daq_channel, hr_max

# %%
def fetch_experimental_data(cellid, max_hours=1000000):

    # To make the dQ/dV plot work, be sure to only select the FORM protocol without
    # including the aging file. Otherwise the time vector will be confused.
    file_indices_to_include = np.array([1,2])

    file_arbin_list, daq_channel, hr_max = fetch_file_list(cellid)

    # Load the Arbin Data
    df_arbin_list = []

    for file in np.array(file_arbin_list)[file_indices_to_include]:

        df = pd.read_csv(file)
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        df['Timestamp']= df['Timestamp'].apply(lambda x : x.tz_localize(None))
        df_arbin_list.append(df)

    df_arbin = pd.concat(df_arbin_list, axis=0)

    # Filter the Arbin Data
    qq = df_arbin['Charge Capacity (Ah)']
    tv = df_arbin['Timestamp'].astype(int)
    tv = (tv - np.min(tv)) / 1e9
    y_voltage = df_arbin['Potential (V)']
    y_current = df_arbin['Current (A)']

    y_voltage.iloc[np.where(tv/3600 > hr_max)] = np.nan
    y_current.iloc[np.where(tv/3600 > hr_max)] = np.nan

    # Load the Keyence data
    file_keyence = f'{target_dir}/data/raw/from-keyence/keyence_20220901_213928.csv'
    df_keyence = pd.read_csv(file_keyence)
    df_keyence['computer time'] = pd.to_datetime(df_keyence['computer time'], unit='s')
    df_keyence['computer time'] = df_keyence['computer time'].apply(lambda x : x.tz_localize(None))

    # Filter the Keyence data
    df_keyence = df_keyence.loc[(df_keyence['computer time'] > df_arbin['Timestamp'].iloc[0]) & \
                                (df_keyence['computer time'] < df_arbin['Timestamp'].iloc[-1])]
    y_strain = df_keyence[daq_channel] - df_keyence[daq_channel].iloc[0]
    y_strain[y_strain > 500] = np.nan

    tt = df_keyence['computer time'].astype(int)
    tt = (tt - np.min(tt)) / 1e9

    y_strain.iloc[np.where(tt/3600 > hr_max)] = np.nan

    out = dict()

    idx = np.where(tv < max_hours*3600)[0]
    out['arbin_time'] = tv.iloc[idx]
    out['arbin_voltage'] = y_voltage.iloc[idx]
    out['arbin_current'] = y_current.iloc[idx]

    idx = np.where(tt < max_hours * 3600)[0]
    out['daq_time'] = tt.iloc[idx]
    out['daq_strain'] = y_strain.iloc[idx]

    return out

# %%
def run_sim(type, diff_ec, diff_vc, gamma_kappa=3000, dt=5.0, 
            to_follow_current=False, current_vec=np.nan,
            to_cycle=False, num_cycles=50):
    """
    Run simulation for a given formation type and target EC diffusivity

    Arguments:
    ----------
    type: 'base', 'fast', 'fast+'
    diff_ec: target EC diffusivity, e.g., 4.2e-20 [m2/s]
    diff_vc: target VC diffusivity, e.g., 6.6e-18 [m2/s]

    Returns:
    ----------

    df_sim: DataFrame with simulation results
    """

    cell = cellsim.Cell()
    cell.load_config('params/default.yaml')

    # Update EC diffusivity
    cell.D_SEI11 = diff_ec
    cell.D_SEI21 = diff_ec

    # Update VC diffusivity
    cell.D_SEI12 = diff_vc
    cell.D_SEI22 = diff_vc

    # Update the GAMMA_KAPPA parameter
    cell.GAMMA_KAPPA = gamma_kappa

    time_base_secs = 80*3600
    time_fast_secs = 20*3600
    time_fast_plus_secs = 10*3600

    if type == 'base':

        sim = cellsim.Simulation(cell, time_base_secs + 3600 * 3 * num_cycles, dt=dt)

        if to_follow_current:
            for k, current in enumerate(current_vec):
                sim.step(k, mode='cc', icc=current, to_debug=False)
                sim.curr_k = k 
            curr_cycle_index = 2

        else: 
            sim.run_rest(1, rest_time_hrs=0.5)
            sim.run_chg_cccv(2, 2.5/10, 2.5/20, 4.2)
            sim.run_rest(2, rest_time_hrs=1/6) 
            sim.run_dch_cccv(2, -2.5/10, -2.5/10, 3.0)
            sim.run_rest(2, rest_time_hrs=1/6) 
            sim.run_chg_cccv(3, 2.5/10, 2.5/20, 4.2)
            sim.run_rest(3, rest_time_hrs=1/6) 
            sim.run_dch_cccv(3, -2.5/10, -2.5/10, 3.0)
            sim.run_rest(3, rest_time_hrs=1/6) 
            sim.run_chg_cccv(4, 2.5/10, 2.5/20, 4.2)
            sim.run_rest(4, rest_time_hrs=1/6) 
            sim.run_dch_cccv(4, -2.5/10, 0.05, 3.0)
            sim.run_rest(4, rest_time_hrs=1/6) 
            sim.run_dch_cccv(4, -2.5/10, 0.05, 3.0)
            sim.run_rest(4, rest_time_hrs=6)
            curr_cycle_index = 5

    elif type == 'fast':

        sim = cellsim.Simulation(cell, time_fast_secs + 3600 * 3 * num_cycles, dt=dt)

        if to_follow_current:
            for k, current in enumerate(current_vec):
                sim.step(k, mode='cc', icc=current, to_debug=False)
                sim.curr_k = k
            curr_cycle_index = 2

        else:
            sim.run_rest(1, rest_time_hrs=0.5)
            sim.run_chg_cccv(2, 2.5, 2.5, 3.9)
            sim.run_chg_cccv(2, 2.5/5, 0.125, 4.2)
            sim.run_rest(2, rest_time_hrs=1/6)
            sim.run_dch_cccv(2, -2.5/5, 2.5/5, 3.9)
            sim.run_rest(2, rest_time_hrs=1/6)
            sim.run_chg_cccv(3, 2.5/5, 0.125, 4.2)
            sim.run_rest(3, rest_time_hrs=1/6)
            sim.run_dch_cccv(3, -2.5/5, 2.5/5, 3.9)
            sim.run_rest(3, rest_time_hrs=1/6)
            sim.run_chg_cccv(4, 2.5/5, 0.125, 4.2)
            sim.run_rest(4, rest_time_hrs=1/6)
            sim.run_dch_cccv(4, -2.5/5, 2.5/5, 3.9)
            sim.run_rest(4, rest_time_hrs=1/6)
            sim.run_chg_cccv(5, 2.5/5, 0.125, 4.2)
            sim.run_rest(5, rest_time_hrs=1/6)
            sim.run_dch_cccv(5, -2.5/5, 2.5/5, 3.9)
            sim.run_rest(5, rest_time_hrs=1/6)
            sim.run_dch_cccv(5, -2.5/1, -0.05, 3.0)
            sim.run_rest(6, rest_time_hrs=3)
            curr_cycle_index = 7

    elif type == 'fast+':

        sim = cellsim.Simulation(cell, time_fast_plus_secs + 3600 * 3 * num_cycles, dt=dt)

        if to_follow_current:
            for k, current in enumerate(current_vec):
                sim.step(k, mode='cc', icc=current, to_debug=False)
                sim.curr_k = k
            curr_cycle_index = 2
        
        else:
            sim.run_rest(1, rest_time_hrs=0.5)
            sim.run_chg_cccv(2, 5.0, 5.0, 3.9)
            sim.run_chg_cccv(2, 2.5, 0.125, 4.2)
            sim.run_rest(2, rest_time_hrs=1/6)
            sim.run_dch_cccv(2, -2.5, 2.5, 3.9)
            sim.run_rest(2, rest_time_hrs=1/6)
            sim.run_chg_cccv(3, 2.5, 0.125, 4.2)
            sim.run_rest(3, rest_time_hrs=1/6)
            sim.run_dch_cccv(3, -2.5, 2.5, 3.9)
            sim.run_rest(3, rest_time_hrs=1/6)
            sim.run_chg_cccv(4, 2.5, 0.125, 4.2)
            sim.run_rest(4, rest_time_hrs=1/6)
            sim.run_dch_cccv(4, -2.5, 2.5, 3.9)
            sim.run_rest(4, rest_time_hrs=1/6)
            sim.run_chg_cccv(5, 2.5, 2.5, 4.2)
            sim.run_rest(5, rest_time_hrs=1/6)
            sim.run_dch_cccv(5, -2.5, 2.5, 3.9)
            sim.run_rest(6, rest_time_hrs=1/6)
            sim.run_dch_cccv(5, -5.0, -0.05, 3.0)
            sim.run_rest(6, rest_time_hrs=3)
            curr_cycle_index = 7
    
    if to_cycle:

        for i in np.arange(curr_cycle_index, curr_cycle_index + num_cycles):
            sim.run_chg_cccv(i, 2.5, 2.5, 4.2)
            sim.run_dch_cccv(i, -2.5, -2.5, 3.0)


    return sim.get_results()

# %%
def calculate_rmse(t_meas, y_meas, t_modl, y_modl,
                   to_plot=False, y_range=None):
    """
    Calculates RMSE error between model and measured data.

    Does not assume measurement vectors are the same size.

    Interpolates the measured data along the model vector

    Parameters:
    ----------
    t_meas: time vector for measured data
    y_meas: measured data
    t_modl: time vector for model data
    y_modl: model data
    y_range: range of y values to include in the RMSE calculation
    to_plot: if True, plots the model and measured data

    Returns:
    ----------
    rmse: root mean square error between model and measured data
    """

    # Create interpolation function for voltage data
    f = interp1d(t_meas, y_meas, bounds_error=False, fill_value=np.nan)

    # Interpolate voltage onto model time points
    y_meas_interp = f(t_modl)

    # Exclude data beyond specified y_range    
    if y_range is not None:
        mask = (y_modl >= y_range[0]) & (y_modl <= y_range[1])
        t_modl = t_modl[mask]
        y_modl = y_modl[mask]
        y_meas_interp = y_meas_interp[mask]

    squared_error = (y_modl - y_meas_interp)**2

    # Compute RMSE between model and measured voltage
    rmse = np.sqrt(np.nanmean(squared_error))

    if to_plot:

        plt.figure()
        plt.plot(t_modl, y_modl, label='Model')
        plt.plot(t_meas, y_meas, label='Measurement')
        plt.plot(t_modl, y_meas_interp, label='Interpolated Measurement', linestyle='--')
        plt.xlabel('t')
        plt.ylabel('y')
        plt.legend()
        plt.show()

    return rmse, t_modl, np.sqrt(squared_error)

# %%
def plot_diffusivity_heatmaps(diff_ec_vec, diff_vc_vec, mat1, mat2, mat3, label, is_error_plot=True, 
                              zmin=None, zmax=None):

#  Create a meshgrid for X and Y axes
    X, Y = np.meshgrid(diff_vc_vec, diff_ec_vec)

# Create subplots for the three formation protocols
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(9, 4))
    [ax.set_xlim([min(diff_vc_vec), max(diff_vc_vec)]) for ax in (ax1, ax2, ax3)]
    [ax.set_ylim([min(diff_ec_vec), max(diff_ec_vec)]) for ax in (ax1, ax2, ax3)]
    [ax.set_xscale('log') for ax in (ax1, ax2, ax3)]
    [ax.set_yscale('log') for ax in (ax1, ax2, ax3)]
    [ax.set_xlabel('$D_{VC}$ (m²/s)') for ax in (ax1, ax2, ax3)]
    [ax.set_ylabel('$D_{EC}$ (m²/s)') for ax in (ax1, ax2, ax3)]
    [ax.grid(True, which="both", ls="-", alpha=0.2) for ax in (ax1, ax2, ax3)]
    import matplotlib.cm as cm
    import matplotlib.colors as mcolors

# Get the colormap and create a discrete version with 10 bins
    cmap = cm.get_cmap('viridis_r', 20)

# Base Formation
    pcm1 = ax1.pcolormesh(X, Y, mat1, shading='auto', cmap=cmap)
    vmin, vmax = np.nanmin(mat1), np.nanmax(mat1)
    plt.colorbar(pcm1, ax=ax1, label=label, orientation='horizontal', pad=0.2)
    pcm1.set_clim(zmin, zmax)
    i, j = np.unravel_index(np.nanargmin(mat1), mat1.shape)
    ax1.set_title('Base Formation')

# Fast Formation
    pcm2 = ax2.pcolormesh(X, Y, mat2, shading='auto', cmap=cmap)
    plt.colorbar(pcm2, ax=ax2, label=label, orientation='horizontal', pad=0.2)
    pcm2.set_clim(zmin, zmax)
    ax2.set_title('Fast Formation')

# Fast+ Formation
    pcm3 = ax3.pcolormesh(X, Y, mat3, shading='auto', cmap=cmap)
    plt.colorbar(pcm3, ax=ax3, label=label, orientation='horizontal', pad=0.2)
    pcm3.set_clim(zmin, zmax)
    ax3.set_title('Fast+ Formation')

    if is_error_plot:
        i, j = np.unravel_index(np.nanargmin(mat1), mat1.shape)
        ax1.plot(diff_vc_vec[j], diff_ec_vec[i], 'r*', markersize=15,
             label=f'Min RMSE at\nD_EC={diff_ec_vec[i]:.2e}\nD_VC={diff_vc_vec[j]:.2e}')
        i, j = np.unravel_index(np.nanargmin(mat2), mat2.shape)
        ax2.plot(diff_vc_vec[j], diff_ec_vec[i], 'r*', markersize=15,
             label=f'Min RMSE at\nD_EC={diff_ec_vec[i]:.2e}\nD_VC={diff_vc_vec[j]:.2e}')
        i, j = np.unravel_index(np.nanargmin(mat3), mat3.shape)
        ax3.plot(diff_vc_vec[j], diff_ec_vec[i], 'r*', markersize=15,
             label=f'Min RMSE at\nD_EC={diff_ec_vec[i]:.2e}\nD_VC={diff_vc_vec[j]:.2e}')

    plt.tight_layout()

# %% [markdown]
# # Load the experimental data

# %%
expt1 = fetch_experimental_data(152064, 65)
# expt2 = fetch_experimental_data(152074)
expt3 = fetch_experimental_data(152071, 16)
expt4 = fetch_experimental_data(152098, 7)
# Out:
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/1404491339.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_voltage.iloc[np.where(tv/3600 > hr_max)] = np.nan
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/1404491339.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_current.iloc[np.where(tv/3600 > hr_max)] = np.nan
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/1404491339.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_voltage.iloc[np.where(tv/3600 > hr_max)] = np.nan
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/1404491339.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_current.iloc[np.where(tv/3600 > hr_max)] = np.nan
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/1404491339.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_voltage.iloc[np.where(tv/3600 > hr_max)] = np.nan
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/1404491339.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_current.iloc[np.where(tv/3600 > hr_max)] = np.nan

# %%
def interpolate_raw_data(t, y, dt):
    """
    Interpolates raw data to a specified time step.
    Parameters:
    ----------
    t: time vector
    y: data vector
    dt: time step for interpolation
    Returns:
    ----------
    t_interp: interpolated time vector
    y_interp: interpolated data vector
    """
    # Create interpolation function for voltage data

    t_interp = np.arange(t.min(), t.max(), dt)
    y_interp = np.interp(t_interp, t, y)

    return t_interp, y_interp

dt_data_interp = 5.0

t_interp1, i_interp1 = interpolate_raw_data(expt1['arbin_time'], expt1['arbin_current'], dt_data_interp)
t_interp3, i_interp3 = interpolate_raw_data(expt3['arbin_time'], expt3['arbin_current'], dt_data_interp)
t_interp4, i_interp4 = interpolate_raw_data(expt4['arbin_time'], expt4['arbin_current'], dt_data_interp)

# %% [markdown]
# # Feed in experimental current to run a simulation

# %%
plt.figure(figsize=(10, 5))
plt.plot(expt1['arbin_time'] / 3600, expt1['arbin_current'], label='Measured Current', color='blue', alpha=0.7)
plt.plot(t_interp1 / 3600, i_interp1, label='Interpolated Current', color='red', linestyle='--', alpha=0.7)
plt.plot(expt3['arbin_time'] / 3600, expt3['arbin_current'], label='Measured Current', color='green', alpha=0.7)
plt.plot(t_interp3 / 3600, i_interp3, label='Interpolated Current', color='orange', linestyle='--', alpha=0.7)
plt.plot(expt4['arbin_time'] / 3600, expt4['arbin_current'], label='Measured Current', color='blue', alpha=0.7)
plt.plot(t_interp4 / 3600, i_interp4, label='Interpolated Current', color='red', linestyle='--', alpha=0.7)
plt.xlabel('Time (hrs)')
plt.ylabel('Current (A)')
plt.title('Measured and Interpolated Current vs Time')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Simulate with measured current
# Feed the experimental current vector into the simulation

# %%
diff_ec = 4.2e-20 * 1e-3 # For EC
diff_vc = 6.6e-18 # For VC
gamma_kappa = 8000

# df_sim1_timesync = run_sim('base', diff_ec, diff_vc, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp1)
# df_sim2_timesync = run_sim('fast', diff_ec, diff_vc, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp3)
# df_sim3_timesync = run_sim('fast+', diff_ec, diff_vc, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp4)

df_sim1 = run_sim('base', diff_ec, diff_vc, gamma_kappa, dt=1, to_cycle=True, num_cycles=250)
df_sim2 = run_sim('fast', diff_ec, diff_vc, gamma_kappa, dt=1, to_cycle=True, num_cycles=250)
df_sim3 = run_sim('fast+', diff_ec, diff_vc, gamma_kappa, dt=1, to_cycle=True, num_cycles=250)
# Out:
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Charge to 4.2V...
# Running Cyc6: Discharge to 3.0V...
# Running Cyc7: Charge to 4.2V...
# Running Cyc7: Discharge to 3.0V...
# Running Cyc8: Charge to 4.2V...
# Running Cyc8: Discharge to 3.0V...
# Running Cyc9: Charge to 4.2V...
# Running Cyc9: Discharge to 3.0V...
# Running Cyc10: Charge to 4.2V...
# Running Cyc10: Discharge to 3.0V...
# Running Cyc11: Charge to 4.2V...
# Running Cyc11: Discharge to 3.0V...
# Running Cyc12: Charge to 4.2V...
# Running Cyc12: Discharge to 3.0V...
# Running Cyc13: Charge to 4.2V...
# Running Cyc13: Discharge to 3.0V...
# Running Cyc14: Charge to 4.2V...
# Running Cyc14: Discharge to 3.0V...
# Running Cyc15: Charge to 4.2V...
# Running Cyc15: Discharge to 3.0V...
# Running Cyc16: Charge to 4.2V...
# Running Cyc16: Discharge to 3.0V...
# Running Cyc17: Charge to 4.2V...
# Running Cyc17: Discharge to 3.0V...
# Running Cyc18: Charge to 4.2V...
# Running Cyc18: Discharge to 3.0V...
# Running Cyc19: Charge to 4.2V...
# Running Cyc19: Discharge to 3.0V...
# Running Cyc20: Charge to 4.2V...
# Running Cyc20: Discharge to 3.0V...
# Running Cyc21: Charge to 4.2V...
# Running Cyc21: Discharge to 3.0V...
# Running Cyc22: Charge to 4.2V...
# Running Cyc22: Discharge to 3.0V...
# Running Cyc23: Charge to 4.2V...
# Running Cyc23: Discharge to 3.0V...
# Running Cyc24: Charge to 4.2V...
# Running Cyc24: Discharge to 3.0V...
# Running Cyc25: Charge to 4.2V...
# Running Cyc25: Discharge to 3.0V...
# Running Cyc26: Charge to 4.2V...
# Running Cyc26: Discharge to 3.0V...
# Running Cyc27: Charge to 4.2V...
# Running Cyc27: Discharge to 3.0V...
# Running Cyc28: Charge to 4.2V...
# Running Cyc28: Discharge to 3.0V...
# Running Cyc29: Charge to 4.2V...
# Running Cyc29: Discharge to 3.0V...
# Running Cyc30: Charge to 4.2V...
# Running Cyc30: Discharge to 3.0V...
# Running Cyc31: Charge to 4.2V...
# Running Cyc31: Discharge to 3.0V...
# Running Cyc32: Charge to 4.2V...
# Running Cyc32: Discharge to 3.0V...
# Running Cyc33: Charge to 4.2V...
# Running Cyc33: Discharge to 3.0V...
# Running Cyc34: Charge to 4.2V...
# Running Cyc34: Discharge to 3.0V...
# Running Cyc35: Charge to 4.2V...
# Running Cyc35: Discharge to 3.0V...
# Running Cyc36: Charge to 4.2V...
# Running Cyc36: Discharge to 3.0V...
# Running Cyc37: Charge to 4.2V...
# Running Cyc37: Discharge to 3.0V...
# Running Cyc38: Charge to 4.2V...
# Running Cyc38: Discharge to 3.0V...
# Running Cyc39: Charge to 4.2V...
# Running Cyc39: Discharge to 3.0V...
# Running Cyc40: Charge to 4.2V...
# Running Cyc40: Discharge to 3.0V...
# Running Cyc41: Charge to 4.2V...
# Running Cyc41: Discharge to 3.0V...
# Running Cyc42: Charge to 4.2V...
# Running Cyc42: Discharge to 3.0V...
# Running Cyc43: Charge to 4.2V...
# Running Cyc43: Discharge to 3.0V...
# Running Cyc44: Charge to 4.2V...
# Running Cyc44: Discharge to 3.0V...
# Running Cyc45: Charge to 4.2V...
# Running Cyc45: Discharge to 3.0V...
# Running Cyc46: Charge to 4.2V...
# Running Cyc46: Discharge to 3.0V...
# Running Cyc47: Charge to 4.2V...
# Running Cyc47: Discharge to 3.0V...
# Running Cyc48: Charge to 4.2V...
# Running Cyc48: Discharge to 3.0V...
# Running Cyc49: Charge to 4.2V...
# Running Cyc49: Discharge to 3.0V...
# Running Cyc50: Charge to 4.2V...
# Running Cyc50: Discharge to 3.0V...
# Running Cyc51: Charge to 4.2V...
# Running Cyc51: Discharge to 3.0V...
# Running Cyc52: Charge to 4.2V...
# Running Cyc52: Discharge to 3.0V...
# Running Cyc53: Charge to 4.2V...
# Running Cyc53: Discharge to 3.0V...
# Running Cyc54: Charge to 4.2V...
# Running Cyc54: Discharge to 3.0V...
# Running Cyc55: Charge to 4.2V...
# Running Cyc55: Discharge to 3.0V...
# Running Cyc56: Charge to 4.2V...
# Running Cyc56: Discharge to 3.0V...
# Running Cyc57: Charge to 4.2V...
# Running Cyc57: Discharge to 3.0V...
# Running Cyc58: Charge to 4.2V...
# Running Cyc58: Discharge to 3.0V...
# Running Cyc59: Charge to 4.2V...
# Running Cyc59: Discharge to 3.0V...
# Running Cyc60: Charge to 4.2V...
# Running Cyc60: Discharge to 3.0V...
# Running Cyc61: Charge to 4.2V...
# Running Cyc61: Discharge to 3.0V...
# Running Cyc62: Charge to 4.2V...
# Running Cyc62: Discharge to 3.0V...
# Running Cyc63: Charge to 4.2V...
# Running Cyc63: Discharge to 3.0V...
# Running Cyc64: Charge to 4.2V...
# Running Cyc64: Discharge to 3.0V...
# Running Cyc65: Charge to 4.2V...
# Running Cyc65: Discharge to 3.0V...
# Running Cyc66: Charge to 4.2V...
# Running Cyc66: Discharge to 3.0V...
# Running Cyc67: Charge to 4.2V...
# Running Cyc67: Discharge to 3.0V...
# Running Cyc68: Charge to 4.2V...
# Running Cyc68: Discharge to 3.0V...
# Running Cyc69: Charge to 4.2V...
# Running Cyc69: Discharge to 3.0V...
# Running Cyc70: Charge to 4.2V...
# Running Cyc70: Discharge to 3.0V...
# Running Cyc71: Charge to 4.2V...
# Running Cyc71: Discharge to 3.0V...
# Running Cyc72: Charge to 4.2V...
# Running Cyc72: Discharge to 3.0V...
# Running Cyc73: Charge to 4.2V...
# Running Cyc73: Discharge to 3.0V...
# Running Cyc74: Charge to 4.2V...
# Running Cyc74: Discharge to 3.0V...
# Running Cyc75: Charge to 4.2V...
# Running Cyc75: Discharge to 3.0V...
# Running Cyc76: Charge to 4.2V...
# Running Cyc76: Discharge to 3.0V...
# Running Cyc77: Charge to 4.2V...
# Running Cyc77: Discharge to 3.0V...
# Running Cyc78: Charge to 4.2V...
# Running Cyc78: Discharge to 3.0V...
# Running Cyc79: Charge to 4.2V...
# Running Cyc79: Discharge to 3.0V...
# Running Cyc80: Charge to 4.2V...
# Running Cyc80: Discharge to 3.0V...
# Running Cyc81: Charge to 4.2V...
# Running Cyc81: Discharge to 3.0V...
# Running Cyc82: Charge to 4.2V...
# Running Cyc82: Discharge to 3.0V...
# Running Cyc83: Charge to 4.2V...
# Running Cyc83: Discharge to 3.0V...
# Running Cyc84: Charge to 4.2V...
# Running Cyc84: Discharge to 3.0V...
# Running Cyc85: Charge to 4.2V...
# Running Cyc85: Discharge to 3.0V...
# Running Cyc86: Charge to 4.2V...
# Running Cyc86: Discharge to 3.0V...
# Running Cyc87: Charge to 4.2V...
# Running Cyc87: Discharge to 3.0V...
# Running Cyc88: Charge to 4.2V...
# Running Cyc88: Discharge to 3.0V...
# Running Cyc89: Charge to 4.2V...
# Running Cyc89: Discharge to 3.0V...
# Running Cyc90: Charge to 4.2V...
# Running Cyc90: Discharge to 3.0V...
# Running Cyc91: Charge to 4.2V...
# Running Cyc91: Discharge to 3.0V...
# Running Cyc92: Charge to 4.2V...
# Running Cyc92: Discharge to 3.0V...
# Running Cyc93: Charge to 4.2V...
# Running Cyc93: Discharge to 3.0V...
# Running Cyc94: Charge to 4.2V...
# Running Cyc94: Discharge to 3.0V...
# Running Cyc95: Charge to 4.2V...
# Running Cyc95: Discharge to 3.0V...
# Running Cyc96: Charge to 4.2V...
# Running Cyc96: Discharge to 3.0V...
# Running Cyc97: Charge to 4.2V...
# Running Cyc97: Discharge to 3.0V...
# Running Cyc98: Charge to 4.2V...
# Running Cyc98: Discharge to 3.0V...
# Running Cyc99: Charge to 4.2V...
# Running Cyc99: Discharge to 3.0V...
# Running Cyc100: Charge to 4.2V...
# Running Cyc100: Discharge to 3.0V...
# Running Cyc101: Charge to 4.2V...
# Running Cyc101: Discharge to 3.0V...
# Running Cyc102: Charge to 4.2V...
# Running Cyc102: Discharge to 3.0V...
# Running Cyc103: Charge to 4.2V...
# Running Cyc103: Discharge to 3.0V...
# Running Cyc104: Charge to 4.2V...
# Running Cyc104: Discharge to 3.0V...
# Running Cyc105: Charge to 4.2V...
# Running Cyc105: Discharge to 3.0V...
# Running Cyc106: Charge to 4.2V...
# Running Cyc106: Discharge to 3.0V...
# Running Cyc107: Charge to 4.2V...
# Running Cyc107: Discharge to 3.0V...
# Running Cyc108: Charge to 4.2V...
# Running Cyc108: Discharge to 3.0V...
# Running Cyc109: Charge to 4.2V...
# Running Cyc109: Discharge to 3.0V...
# Running Cyc110: Charge to 4.2V...
# Running Cyc110: Discharge to 3.0V...
# Running Cyc111: Charge to 4.2V...
# Running Cyc111: Discharge to 3.0V...
# Running Cyc112: Charge to 4.2V...
# Running Cyc112: Discharge to 3.0V...
# Running Cyc113: Charge to 4.2V...
# Running Cyc113: Discharge to 3.0V...
# Running Cyc114: Charge to 4.2V...
# Running Cyc114: Discharge to 3.0V...
# Running Cyc115: Charge to 4.2V...
# Running Cyc115: Discharge to 3.0V...
# Running Cyc116: Charge to 4.2V...
# Running Cyc116: Discharge to 3.0V...
# Running Cyc117: Charge to 4.2V...
# Running Cyc117: Discharge to 3.0V...
# Running Cyc118: Charge to 4.2V...
# Running Cyc118: Discharge to 3.0V...
# Running Cyc119: Charge to 4.2V...
# Running Cyc119: Discharge to 3.0V...
# Running Cyc120: Charge to 4.2V...
# Running Cyc120: Discharge to 3.0V...
# Running Cyc121: Charge to 4.2V...
# Running Cyc121: Discharge to 3.0V...
# Running Cyc122: Charge to 4.2V...
# Running Cyc122: Discharge to 3.0V...
# Running Cyc123: Charge to 4.2V...
# Running Cyc123: Discharge to 3.0V...
# Running Cyc124: Charge to 4.2V...
# Running Cyc124: Discharge to 3.0V...
# Running Cyc125: Charge to 4.2V...
# Running Cyc125: Discharge to 3.0V...
# Running Cyc126: Charge to 4.2V...
# Running Cyc126: Discharge to 3.0V...
# Running Cyc127: Charge to 4.2V...
# Running Cyc127: Discharge to 3.0V...
# Running Cyc128: Charge to 4.2V...
# Running Cyc128: Discharge to 3.0V...
# Running Cyc129: Charge to 4.2V...
# Running Cyc129: Discharge to 3.0V...
# Running Cyc130: Charge to 4.2V...
# Running Cyc130: Discharge to 3.0V...
# Running Cyc131: Charge to 4.2V...
# Running Cyc131: Discharge to 3.0V...
# Running Cyc132: Charge to 4.2V...
# Running Cyc132: Discharge to 3.0V...
# Running Cyc133: Charge to 4.2V...
# Running Cyc133: Discharge to 3.0V...
# Running Cyc134: Charge to 4.2V...
# Running Cyc134: Discharge to 3.0V...
# Running Cyc135: Charge to 4.2V...
# Running Cyc135: Discharge to 3.0V...
# Running Cyc136: Charge to 4.2V...
# Running Cyc136: Discharge to 3.0V...
# Running Cyc137: Charge to 4.2V...
# Running Cyc137: Discharge to 3.0V...
# Running Cyc138: Charge to 4.2V...
# Running Cyc138: Discharge to 3.0V...
# Running Cyc139: Charge to 4.2V...
# Running Cyc139: Discharge to 3.0V...
# Running Cyc140: Charge to 4.2V...
# Running Cyc140: Discharge to 3.0V...
# Running Cyc141: Charge to 4.2V...
# Running Cyc141: Discharge to 3.0V...
# Running Cyc142: Charge to 4.2V...
# Running Cyc142: Discharge to 3.0V...
# Running Cyc143: Charge to 4.2V...
# Running Cyc143: Discharge to 3.0V...
# Running Cyc144: Charge to 4.2V...
# Running Cyc144: Discharge to 3.0V...
# Running Cyc145: Charge to 4.2V...
# Running Cyc145: Discharge to 3.0V...
# Running Cyc146: Charge to 4.2V...
# Running Cyc146: Discharge to 3.0V...
# Running Cyc147: Charge to 4.2V...
# Running Cyc147: Discharge to 3.0V...
# Running Cyc148: Charge to 4.2V...
# Running Cyc148: Discharge to 3.0V...
# Running Cyc149: Charge to 4.2V...
# Running Cyc149: Discharge to 3.0V...
# Running Cyc150: Charge to 4.2V...
# Running Cyc150: Discharge to 3.0V...
# Running Cyc151: Charge to 4.2V...
# Running Cyc151: Discharge to 3.0V...
# Running Cyc152: Charge to 4.2V...
# Running Cyc152: Discharge to 3.0V...
# Running Cyc153: Charge to 4.2V...
# Running Cyc153: Discharge to 3.0V...
# Running Cyc154: Charge to 4.2V...
# Running Cyc154: Discharge to 3.0V...
# Running Cyc155: Charge to 4.2V...
# Running Cyc155: Discharge to 3.0V...
# Running Cyc156: Charge to 4.2V...
# Running Cyc156: Discharge to 3.0V...
# Running Cyc157: Charge to 4.2V...
# Running Cyc157: Discharge to 3.0V...
# Running Cyc158: Charge to 4.2V...
# Running Cyc158: Discharge to 3.0V...
# Running Cyc159: Charge to 4.2V...
# Running Cyc159: Discharge to 3.0V...
# Running Cyc160: Charge to 4.2V...
# Running Cyc160: Discharge to 3.0V...
# Running Cyc161: Charge to 4.2V...
# Running Cyc161: Discharge to 3.0V...
# Running Cyc162: Charge to 4.2V...
# Running Cyc162: Discharge to 3.0V...
# Running Cyc163: Charge to 4.2V...
# Running Cyc163: Discharge to 3.0V...
# Running Cyc164: Charge to 4.2V...
# Running Cyc164: Discharge to 3.0V...
# Running Cyc165: Charge to 4.2V...
# Running Cyc165: Discharge to 3.0V...
# Running Cyc166: Charge to 4.2V...
# Running Cyc166: Discharge to 3.0V...
# Running Cyc167: Charge to 4.2V...
# Running Cyc167: Discharge to 3.0V...
# Running Cyc168: Charge to 4.2V...
# Running Cyc168: Discharge to 3.0V...
# Running Cyc169: Charge to 4.2V...
# Running Cyc169: Discharge to 3.0V...
# Running Cyc170: Charge to 4.2V...
# Running Cyc170: Discharge to 3.0V...
# Running Cyc171: Charge to 4.2V...
# Running Cyc171: Discharge to 3.0V...
# Running Cyc172: Charge to 4.2V...
# Running Cyc172: Discharge to 3.0V...
# Running Cyc173: Charge to 4.2V...
# Running Cyc173: Discharge to 3.0V...
# Running Cyc174: Charge to 4.2V...
# Running Cyc174: Discharge to 3.0V...
# Running Cyc175: Charge to 4.2V...
# Running Cyc175: Discharge to 3.0V...
# Running Cyc176: Charge to 4.2V...
# Running Cyc176: Discharge to 3.0V...
# Running Cyc177: Charge to 4.2V...
# Running Cyc177: Discharge to 3.0V...
# Running Cyc178: Charge to 4.2V...
# Running Cyc178: Discharge to 3.0V...
# Running Cyc179: Charge to 4.2V...
# Running Cyc179: Discharge to 3.0V...
# Running Cyc180: Charge to 4.2V...
# Running Cyc180: Discharge to 3.0V...
# Running Cyc181: Charge to 4.2V...
# Running Cyc181: Discharge to 3.0V...
# Running Cyc182: Charge to 4.2V...
# Running Cyc182: Discharge to 3.0V...
# Running Cyc183: Charge to 4.2V...
# Running Cyc183: Discharge to 3.0V...
# Running Cyc184: Charge to 4.2V...
# Running Cyc184: Discharge to 3.0V...
# Running Cyc185: Charge to 4.2V...
# Running Cyc185: Discharge to 3.0V...
# Running Cyc186: Charge to 4.2V...
# Running Cyc186: Discharge to 3.0V...
# Running Cyc187: Charge to 4.2V...
# Running Cyc187: Discharge to 3.0V...
# Running Cyc188: Charge to 4.2V...
# Running Cyc188: Discharge to 3.0V...
# Running Cyc189: Charge to 4.2V...
# Running Cyc189: Discharge to 3.0V...
# Running Cyc190: Charge to 4.2V...
# Running Cyc190: Discharge to 3.0V...
# Running Cyc191: Charge to 4.2V...
# Running Cyc191: Discharge to 3.0V...
# Running Cyc192: Charge to 4.2V...
# Running Cyc192: Discharge to 3.0V...
# Running Cyc193: Charge to 4.2V...
# Running Cyc193: Discharge to 3.0V...
# Running Cyc194: Charge to 4.2V...
# Running Cyc194: Discharge to 3.0V...
# Running Cyc195: Charge to 4.2V...
# Running Cyc195: Discharge to 3.0V...
# Running Cyc196: Charge to 4.2V...
# Running Cyc196: Discharge to 3.0V...
# Running Cyc197: Charge to 4.2V...
# Running Cyc197: Discharge to 3.0V...
# Running Cyc198: Charge to 4.2V...
# Running Cyc198: Discharge to 3.0V...
# Running Cyc199: Charge to 4.2V...
# Running Cyc199: Discharge to 3.0V...
# Running Cyc200: Charge to 4.2V...
# Running Cyc200: Discharge to 3.0V...
# Running Cyc201: Charge to 4.2V...
# Running Cyc201: Discharge to 3.0V...
# Running Cyc202: Charge to 4.2V...
# Running Cyc202: Discharge to 3.0V...
# Running Cyc203: Charge to 4.2V...
# Running Cyc203: Discharge to 3.0V...
# Running Cyc204: Charge to 4.2V...
# Running Cyc204: Discharge to 3.0V...
# Running Cyc205: Charge to 4.2V...
# Running Cyc205: Discharge to 3.0V...
# Running Cyc206: Charge to 4.2V...
# Running Cyc206: Discharge to 3.0V...
# Running Cyc207: Charge to 4.2V...
# Running Cyc207: Discharge to 3.0V...
# Running Cyc208: Charge to 4.2V...
# Running Cyc208: Discharge to 3.0V...
# Running Cyc209: Charge to 4.2V...
# Running Cyc209: Discharge to 3.0V...
# Running Cyc210: Charge to 4.2V...
# Running Cyc210: Discharge to 3.0V...
# Running Cyc211: Charge to 4.2V...
# Running Cyc211: Discharge to 3.0V...
# Running Cyc212: Charge to 4.2V...
# Running Cyc212: Discharge to 3.0V...
# Running Cyc213: Charge to 4.2V...
# Running Cyc213: Discharge to 3.0V...
# Running Cyc214: Charge to 4.2V...
# Running Cyc214: Discharge to 3.0V...
# Running Cyc215: Charge to 4.2V...
# Running Cyc215: Discharge to 3.0V...
# Running Cyc216: Charge to 4.2V...
# Running Cyc216: Discharge to 3.0V...
# Running Cyc217: Charge to 4.2V...
# Running Cyc217: Discharge to 3.0V...
# Running Cyc218: Charge to 4.2V...
# Running Cyc218: Discharge to 3.0V...
# Running Cyc219: Charge to 4.2V...
# Running Cyc219: Discharge to 3.0V...
# Running Cyc220: Charge to 4.2V...
# Running Cyc220: Discharge to 3.0V...
# Running Cyc221: Charge to 4.2V...
# Running Cyc221: Discharge to 3.0V...
# Running Cyc222: Charge to 4.2V...
# Running Cyc222: Discharge to 3.0V...
# Running Cyc223: Charge to 4.2V...
# Running Cyc223: Discharge to 3.0V...
# Running Cyc224: Charge to 4.2V...
# Running Cyc224: Discharge to 3.0V...
# Running Cyc225: Charge to 4.2V...
# Running Cyc225: Discharge to 3.0V...
# Running Cyc226: Charge to 4.2V...
# Running Cyc226: Discharge to 3.0V...
# Running Cyc227: Charge to 4.2V...
# Running Cyc227: Discharge to 3.0V...
# Running Cyc228: Charge to 4.2V...
# Running Cyc228: Discharge to 3.0V...
# Running Cyc229: Charge to 4.2V...
# Running Cyc229: Discharge to 3.0V...
# Running Cyc230: Charge to 4.2V...
# Running Cyc230: Discharge to 3.0V...
# Running Cyc231: Charge to 4.2V...
# Running Cyc231: Discharge to 3.0V...
# Running Cyc232: Charge to 4.2V...
# Running Cyc232: Discharge to 3.0V...
# Running Cyc233: Charge to 4.2V...
# Running Cyc233: Discharge to 3.0V...
# Running Cyc234: Charge to 4.2V...
# Running Cyc234: Discharge to 3.0V...
# Running Cyc235: Charge to 4.2V...
# Running Cyc235: Discharge to 3.0V...
# Running Cyc236: Charge to 4.2V...
# Running Cyc236: Discharge to 3.0V...
# Running Cyc237: Charge to 4.2V...
# Running Cyc237: Discharge to 3.0V...
# Running Cyc238: Charge to 4.2V...
# Running Cyc238: Discharge to 3.0V...
# Running Cyc239: Charge to 4.2V...
# Running Cyc239: Discharge to 3.0V...
# Running Cyc240: Charge to 4.2V...
# Running Cyc240: Discharge to 3.0V...
# Running Cyc241: Charge to 4.2V...
# Running Cyc241: Discharge to 3.0V...
# Running Cyc242: Charge to 4.2V...
# Running Cyc242: Discharge to 3.0V...
# Running Cyc243: Charge to 4.2V...
# Running Cyc243: Discharge to 3.0V...
# Running Cyc244: Charge to 4.2V...
# Running Cyc244: Discharge to 3.0V...
# Running Cyc245: Charge to 4.2V...
# Running Cyc245: Discharge to 3.0V...
# Running Cyc246: Charge to 4.2V...
# Running Cyc246: Discharge to 3.0V...
# Running Cyc247: Charge to 4.2V...
# Running Cyc247: Discharge to 3.0V...
# Running Cyc248: Charge to 4.2V...
# Running Cyc248: Discharge to 3.0V...
# Running Cyc249: Charge to 4.2V...
# Running Cyc249: Discharge to 3.0V...
# Running Cyc250: Charge to 4.2V...
# Running Cyc250: Discharge to 3.0V...
# Running Cyc251: Charge to 4.2V...
# Running Cyc251: Discharge to 3.0V...
# Running Cyc252: Charge to 4.2V...
# Running Cyc252: Discharge to 3.0V...
# Running Cyc253: Charge to 4.2V...
# Running Cyc253: Discharge to 3.0V...
# Running Cyc254: Charge to 4.2V...
# Running Cyc254: Discharge to 3.0V...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc7: Charge to 4.2V...
# Running Cyc7: Discharge to 3.0V...
# Running Cyc8: Charge to 4.2V...
# Running Cyc8: Discharge to 3.0V...
# Running Cyc9: Charge to 4.2V...
# Running Cyc9: Discharge to 3.0V...
# Running Cyc10: Charge to 4.2V...
# Running Cyc10: Discharge to 3.0V...
# Running Cyc11: Charge to 4.2V...
# Running Cyc11: Discharge to 3.0V...
# Running Cyc12: Charge to 4.2V...
# Running Cyc12: Discharge to 3.0V...
# Running Cyc13: Charge to 4.2V...
# Running Cyc13: Discharge to 3.0V...
# Running Cyc14: Charge to 4.2V...
# Running Cyc14: Discharge to 3.0V...
# Running Cyc15: Charge to 4.2V...
# Running Cyc15: Discharge to 3.0V...
# Running Cyc16: Charge to 4.2V...
# Running Cyc16: Discharge to 3.0V...
# Running Cyc17: Charge to 4.2V...
# Running Cyc17: Discharge to 3.0V...
# Running Cyc18: Charge to 4.2V...
# Running Cyc18: Discharge to 3.0V...
# Running Cyc19: Charge to 4.2V...
# Running Cyc19: Discharge to 3.0V...
# Running Cyc20: Charge to 4.2V...
# Running Cyc20: Discharge to 3.0V...
# Running Cyc21: Charge to 4.2V...
# Running Cyc21: Discharge to 3.0V...
# Running Cyc22: Charge to 4.2V...
# Running Cyc22: Discharge to 3.0V...
# Running Cyc23: Charge to 4.2V...
# Running Cyc23: Discharge to 3.0V...
# Running Cyc24: Charge to 4.2V...
# Running Cyc24: Discharge to 3.0V...
# Running Cyc25: Charge to 4.2V...
# Running Cyc25: Discharge to 3.0V...
# Running Cyc26: Charge to 4.2V...
# Running Cyc26: Discharge to 3.0V...
# Running Cyc27: Charge to 4.2V...
# Running Cyc27: Discharge to 3.0V...
# Running Cyc28: Charge to 4.2V...
# Running Cyc28: Discharge to 3.0V...
# Running Cyc29: Charge to 4.2V...
# Running Cyc29: Discharge to 3.0V...
# Running Cyc30: Charge to 4.2V...
# Running Cyc30: Discharge to 3.0V...
# Running Cyc31: Charge to 4.2V...
# Running Cyc31: Discharge to 3.0V...
# Running Cyc32: Charge to 4.2V...
# Running Cyc32: Discharge to 3.0V...
# Running Cyc33: Charge to 4.2V...
# Running Cyc33: Discharge to 3.0V...
# Running Cyc34: Charge to 4.2V...
# Running Cyc34: Discharge to 3.0V...
# Running Cyc35: Charge to 4.2V...
# Running Cyc35: Discharge to 3.0V...
# Running Cyc36: Charge to 4.2V...
# Running Cyc36: Discharge to 3.0V...
# Running Cyc37: Charge to 4.2V...
# Running Cyc37: Discharge to 3.0V...
# Running Cyc38: Charge to 4.2V...
# Running Cyc38: Discharge to 3.0V...
# Running Cyc39: Charge to 4.2V...
# Running Cyc39: Discharge to 3.0V...
# Running Cyc40: Charge to 4.2V...
# Running Cyc40: Discharge to 3.0V...
# Running Cyc41: Charge to 4.2V...
# Running Cyc41: Discharge to 3.0V...
# Running Cyc42: Charge to 4.2V...
# Running Cyc42: Discharge to 3.0V...
# Running Cyc43: Charge to 4.2V...
# Running Cyc43: Discharge to 3.0V...
# Running Cyc44: Charge to 4.2V...
# Running Cyc44: Discharge to 3.0V...
# Running Cyc45: Charge to 4.2V...
# Running Cyc45: Discharge to 3.0V...
# Running Cyc46: Charge to 4.2V...
# Running Cyc46: Discharge to 3.0V...
# Running Cyc47: Charge to 4.2V...
# Running Cyc47: Discharge to 3.0V...
# Running Cyc48: Charge to 4.2V...
# Running Cyc48: Discharge to 3.0V...
# Running Cyc49: Charge to 4.2V...
# Running Cyc49: Discharge to 3.0V...
# Running Cyc50: Charge to 4.2V...
# Running Cyc50: Discharge to 3.0V...
# Running Cyc51: Charge to 4.2V...
# Running Cyc51: Discharge to 3.0V...
# Running Cyc52: Charge to 4.2V...
# Running Cyc52: Discharge to 3.0V...
# Running Cyc53: Charge to 4.2V...
# Running Cyc53: Discharge to 3.0V...
# Running Cyc54: Charge to 4.2V...
# Running Cyc54: Discharge to 3.0V...
# Running Cyc55: Charge to 4.2V...
# Running Cyc55: Discharge to 3.0V...
# Running Cyc56: Charge to 4.2V...
# Running Cyc56: Discharge to 3.0V...
# Running Cyc57: Charge to 4.2V...
# Running Cyc57: Discharge to 3.0V...
# Running Cyc58: Charge to 4.2V...
# Running Cyc58: Discharge to 3.0V...
# Running Cyc59: Charge to 4.2V...
# Running Cyc59: Discharge to 3.0V...
# Running Cyc60: Charge to 4.2V...
# Running Cyc60: Discharge to 3.0V...
# Running Cyc61: Charge to 4.2V...
# Running Cyc61: Discharge to 3.0V...
# Running Cyc62: Charge to 4.2V...
# Running Cyc62: Discharge to 3.0V...
# Running Cyc63: Charge to 4.2V...
# Running Cyc63: Discharge to 3.0V...
# Running Cyc64: Charge to 4.2V...
# Running Cyc64: Discharge to 3.0V...
# Running Cyc65: Charge to 4.2V...
# Running Cyc65: Discharge to 3.0V...
# Running Cyc66: Charge to 4.2V...
# Running Cyc66: Discharge to 3.0V...
# Running Cyc67: Charge to 4.2V...
# Running Cyc67: Discharge to 3.0V...
# Running Cyc68: Charge to 4.2V...
# Running Cyc68: Discharge to 3.0V...
# Running Cyc69: Charge to 4.2V...
# Running Cyc69: Discharge to 3.0V...
# Running Cyc70: Charge to 4.2V...
# Running Cyc70: Discharge to 3.0V...
# Running Cyc71: Charge to 4.2V...
# Running Cyc71: Discharge to 3.0V...
# Running Cyc72: Charge to 4.2V...
# Running Cyc72: Discharge to 3.0V...
# Running Cyc73: Charge to 4.2V...
# Running Cyc73: Discharge to 3.0V...
# Running Cyc74: Charge to 4.2V...
# Running Cyc74: Discharge to 3.0V...
# Running Cyc75: Charge to 4.2V...
# Running Cyc75: Discharge to 3.0V...
# Running Cyc76: Charge to 4.2V...
# Running Cyc76: Discharge to 3.0V...
# Running Cyc77: Charge to 4.2V...
# Running Cyc77: Discharge to 3.0V...
# Running Cyc78: Charge to 4.2V...
# Running Cyc78: Discharge to 3.0V...
# Running Cyc79: Charge to 4.2V...
# Running Cyc79: Discharge to 3.0V...
# Running Cyc80: Charge to 4.2V...
# Running Cyc80: Discharge to 3.0V...
# Running Cyc81: Charge to 4.2V...
# Running Cyc81: Discharge to 3.0V...
# Running Cyc82: Charge to 4.2V...
# Running Cyc82: Discharge to 3.0V...
# Running Cyc83: Charge to 4.2V...
# Running Cyc83: Discharge to 3.0V...
# Running Cyc84: Charge to 4.2V...
# Running Cyc84: Discharge to 3.0V...
# Running Cyc85: Charge to 4.2V...
# Running Cyc85: Discharge to 3.0V...
# Running Cyc86: Charge to 4.2V...
# Running Cyc86: Discharge to 3.0V...
# Running Cyc87: Charge to 4.2V...
# Running Cyc87: Discharge to 3.0V...
# Running Cyc88: Charge to 4.2V...
# Running Cyc88: Discharge to 3.0V...
# Running Cyc89: Charge to 4.2V...
# Running Cyc89: Discharge to 3.0V...
# Running Cyc90: Charge to 4.2V...
# Running Cyc90: Discharge to 3.0V...
# Running Cyc91: Charge to 4.2V...
# Running Cyc91: Discharge to 3.0V...
# Running Cyc92: Charge to 4.2V...
# Running Cyc92: Discharge to 3.0V...
# Running Cyc93: Charge to 4.2V...
# Running Cyc93: Discharge to 3.0V...
# Running Cyc94: Charge to 4.2V...
# Running Cyc94: Discharge to 3.0V...
# Running Cyc95: Charge to 4.2V...
# Running Cyc95: Discharge to 3.0V...
# Running Cyc96: Charge to 4.2V...
# Running Cyc96: Discharge to 3.0V...
# Running Cyc97: Charge to 4.2V...
# Running Cyc97: Discharge to 3.0V...
# Running Cyc98: Charge to 4.2V...
# Running Cyc98: Discharge to 3.0V...
# Running Cyc99: Charge to 4.2V...
# Running Cyc99: Discharge to 3.0V...
# Running Cyc100: Charge to 4.2V...
# Running Cyc100: Discharge to 3.0V...
# Running Cyc101: Charge to 4.2V...
# Running Cyc101: Discharge to 3.0V...
# Running Cyc102: Charge to 4.2V...
# Running Cyc102: Discharge to 3.0V...
# Running Cyc103: Charge to 4.2V...
# Running Cyc103: Discharge to 3.0V...
# Running Cyc104: Charge to 4.2V...
# Running Cyc104: Discharge to 3.0V...
# Running Cyc105: Charge to 4.2V...
# Running Cyc105: Discharge to 3.0V...
# Running Cyc106: Charge to 4.2V...
# Running Cyc106: Discharge to 3.0V...
# Running Cyc107: Charge to 4.2V...
# Running Cyc107: Discharge to 3.0V...
# Running Cyc108: Charge to 4.2V...
# Running Cyc108: Discharge to 3.0V...
# Running Cyc109: Charge to 4.2V...
# Running Cyc109: Discharge to 3.0V...
# Running Cyc110: Charge to 4.2V...
# Running Cyc110: Discharge to 3.0V...
# Running Cyc111: Charge to 4.2V...
# Running Cyc111: Discharge to 3.0V...
# Running Cyc112: Charge to 4.2V...
# Running Cyc112: Discharge to 3.0V...
# Running Cyc113: Charge to 4.2V...
# Running Cyc113: Discharge to 3.0V...
# Running Cyc114: Charge to 4.2V...
# Running Cyc114: Discharge to 3.0V...
# Running Cyc115: Charge to 4.2V...
# Running Cyc115: Discharge to 3.0V...
# Running Cyc116: Charge to 4.2V...
# Running Cyc116: Discharge to 3.0V...
# Running Cyc117: Charge to 4.2V...
# Running Cyc117: Discharge to 3.0V...
# Running Cyc118: Charge to 4.2V...
# Running Cyc118: Discharge to 3.0V...
# Running Cyc119: Charge to 4.2V...
# Running Cyc119: Discharge to 3.0V...
# Running Cyc120: Charge to 4.2V...
# Running Cyc120: Discharge to 3.0V...
# Running Cyc121: Charge to 4.2V...
# Running Cyc121: Discharge to 3.0V...
# Running Cyc122: Charge to 4.2V...
# Running Cyc122: Discharge to 3.0V...
# Running Cyc123: Charge to 4.2V...
# Running Cyc123: Discharge to 3.0V...
# Running Cyc124: Charge to 4.2V...
# Running Cyc124: Discharge to 3.0V...
# Running Cyc125: Charge to 4.2V...
# Running Cyc125: Discharge to 3.0V...
# Running Cyc126: Charge to 4.2V...
# Running Cyc126: Discharge to 3.0V...
# Running Cyc127: Charge to 4.2V...
# Running Cyc127: Discharge to 3.0V...
# Running Cyc128: Charge to 4.2V...
# Running Cyc128: Discharge to 3.0V...
# Running Cyc129: Charge to 4.2V...
# Running Cyc129: Discharge to 3.0V...
# Running Cyc130: Charge to 4.2V...
# Running Cyc130: Discharge to 3.0V...
# Running Cyc131: Charge to 4.2V...
# Running Cyc131: Discharge to 3.0V...
# Running Cyc132: Charge to 4.2V...
# Running Cyc132: Discharge to 3.0V...
# Running Cyc133: Charge to 4.2V...
# Running Cyc133: Discharge to 3.0V...
# Running Cyc134: Charge to 4.2V...
# Running Cyc134: Discharge to 3.0V...
# Running Cyc135: Charge to 4.2V...
# Running Cyc135: Discharge to 3.0V...
# Running Cyc136: Charge to 4.2V...
# Running Cyc136: Discharge to 3.0V...
# Running Cyc137: Charge to 4.2V...
# Running Cyc137: Discharge to 3.0V...
# Running Cyc138: Charge to 4.2V...
# Running Cyc138: Discharge to 3.0V...
# Running Cyc139: Charge to 4.2V...
# Running Cyc139: Discharge to 3.0V...
# Running Cyc140: Charge to 4.2V...
# Running Cyc140: Discharge to 3.0V...
# Running Cyc141: Charge to 4.2V...
# Running Cyc141: Discharge to 3.0V...
# Running Cyc142: Charge to 4.2V...
# Running Cyc142: Discharge to 3.0V...
# Running Cyc143: Charge to 4.2V...
# Running Cyc143: Discharge to 3.0V...
# Running Cyc144: Charge to 4.2V...
# Running Cyc144: Discharge to 3.0V...
# Running Cyc145: Charge to 4.2V...
# Running Cyc145: Discharge to 3.0V...
# Running Cyc146: Charge to 4.2V...
# Running Cyc146: Discharge to 3.0V...
# Running Cyc147: Charge to 4.2V...
# Running Cyc147: Discharge to 3.0V...
# Running Cyc148: Charge to 4.2V...
# Running Cyc148: Discharge to 3.0V...
# Running Cyc149: Charge to 4.2V...
# Running Cyc149: Discharge to 3.0V...
# Running Cyc150: Charge to 4.2V...
# Running Cyc150: Discharge to 3.0V...
# Running Cyc151: Charge to 4.2V...
# Running Cyc151: Discharge to 3.0V...
# Running Cyc152: Charge to 4.2V...
# Running Cyc152: Discharge to 3.0V...
# Running Cyc153: Charge to 4.2V...
# Running Cyc153: Discharge to 3.0V...
# Running Cyc154: Charge to 4.2V...
# Running Cyc154: Discharge to 3.0V...
# Running Cyc155: Charge to 4.2V...
# Running Cyc155: Discharge to 3.0V...
# Running Cyc156: Charge to 4.2V...
# Running Cyc156: Discharge to 3.0V...
# Running Cyc157: Charge to 4.2V...
# Running Cyc157: Discharge to 3.0V...
# Running Cyc158: Charge to 4.2V...
# Running Cyc158: Discharge to 3.0V...
# Running Cyc159: Charge to 4.2V...
# Running Cyc159: Discharge to 3.0V...
# Running Cyc160: Charge to 4.2V...
# Running Cyc160: Discharge to 3.0V...
# Running Cyc161: Charge to 4.2V...
# Running Cyc161: Discharge to 3.0V...
# Running Cyc162: Charge to 4.2V...
# Running Cyc162: Discharge to 3.0V...
# Running Cyc163: Charge to 4.2V...
# Running Cyc163: Discharge to 3.0V...
# Running Cyc164: Charge to 4.2V...
# Running Cyc164: Discharge to 3.0V...
# Running Cyc165: Charge to 4.2V...
# Running Cyc165: Discharge to 3.0V...
# Running Cyc166: Charge to 4.2V...
# Running Cyc166: Discharge to 3.0V...
# Running Cyc167: Charge to 4.2V...
# Running Cyc167: Discharge to 3.0V...
# Running Cyc168: Charge to 4.2V...
# Running Cyc168: Discharge to 3.0V...
# Running Cyc169: Charge to 4.2V...
# Running Cyc169: Discharge to 3.0V...
# Running Cyc170: Charge to 4.2V...
# Running Cyc170: Discharge to 3.0V...
# Running Cyc171: Charge to 4.2V...
# Running Cyc171: Discharge to 3.0V...
# Running Cyc172: Charge to 4.2V...
# Running Cyc172: Discharge to 3.0V...
# Running Cyc173: Charge to 4.2V...
# Running Cyc173: Discharge to 3.0V...
# Running Cyc174: Charge to 4.2V...
# Running Cyc174: Discharge to 3.0V...
# Running Cyc175: Charge to 4.2V...
# Running Cyc175: Discharge to 3.0V...
# Running Cyc176: Charge to 4.2V...
# Running Cyc176: Discharge to 3.0V...
# Running Cyc177: Charge to 4.2V...
# Running Cyc177: Discharge to 3.0V...
# Running Cyc178: Charge to 4.2V...
# Running Cyc178: Discharge to 3.0V...
# Running Cyc179: Charge to 4.2V...
# Running Cyc179: Discharge to 3.0V...
# Running Cyc180: Charge to 4.2V...
# Running Cyc180: Discharge to 3.0V...
# Running Cyc181: Charge to 4.2V...
# Running Cyc181: Discharge to 3.0V...
# Running Cyc182: Charge to 4.2V...
# Running Cyc182: Discharge to 3.0V...
# Running Cyc183: Charge to 4.2V...
# Running Cyc183: Discharge to 3.0V...
# Running Cyc184: Charge to 4.2V...
# Running Cyc184: Discharge to 3.0V...
# Running Cyc185: Charge to 4.2V...
# Running Cyc185: Discharge to 3.0V...
# Running Cyc186: Charge to 4.2V...
# Running Cyc186: Discharge to 3.0V...
# Running Cyc187: Charge to 4.2V...
# Running Cyc187: Discharge to 3.0V...
# Running Cyc188: Charge to 4.2V...
# Running Cyc188: Discharge to 3.0V...
# Running Cyc189: Charge to 4.2V...
# Running Cyc189: Discharge to 3.0V...
# Running Cyc190: Charge to 4.2V...
# Running Cyc190: Discharge to 3.0V...
# Running Cyc191: Charge to 4.2V...
# Running Cyc191: Discharge to 3.0V...
# Running Cyc192: Charge to 4.2V...
# Running Cyc192: Discharge to 3.0V...
# Running Cyc193: Charge to 4.2V...
# Running Cyc193: Discharge to 3.0V...
# Running Cyc194: Charge to 4.2V...
# Running Cyc194: Discharge to 3.0V...
# Running Cyc195: Charge to 4.2V...
# Running Cyc195: Discharge to 3.0V...
# Running Cyc196: Charge to 4.2V...
# Running Cyc196: Discharge to 3.0V...
# Running Cyc197: Charge to 4.2V...
# Running Cyc197: Discharge to 3.0V...
# Running Cyc198: Charge to 4.2V...
# Running Cyc198: Discharge to 3.0V...
# Running Cyc199: Charge to 4.2V...
# Running Cyc199: Discharge to 3.0V...
# Running Cyc200: Charge to 4.2V...
# Running Cyc200: Discharge to 3.0V...
# Running Cyc201: Charge to 4.2V...
# Running Cyc201: Discharge to 3.0V...
# Running Cyc202: Charge to 4.2V...
# Running Cyc202: Discharge to 3.0V...
# Running Cyc203: Charge to 4.2V...
# Running Cyc203: Discharge to 3.0V...
# Running Cyc204: Charge to 4.2V...
# Running Cyc204: Discharge to 3.0V...
# Running Cyc205: Charge to 4.2V...
# Running Cyc205: Discharge to 3.0V...
# Running Cyc206: Charge to 4.2V...
# Running Cyc206: Discharge to 3.0V...
# Running Cyc207: Charge to 4.2V...
# Running Cyc207: Discharge to 3.0V...
# Running Cyc208: Charge to 4.2V...
# Running Cyc208: Discharge to 3.0V...
# Running Cyc209: Charge to 4.2V...
# Running Cyc209: Discharge to 3.0V...
# Running Cyc210: Charge to 4.2V...
# Running Cyc210: Discharge to 3.0V...
# Running Cyc211: Charge to 4.2V...
# Running Cyc211: Discharge to 3.0V...
# Running Cyc212: Charge to 4.2V...
# Running Cyc212: Discharge to 3.0V...
# Running Cyc213: Charge to 4.2V...
# Running Cyc213: Discharge to 3.0V...
# Running Cyc214: Charge to 4.2V...
# Running Cyc214: Discharge to 3.0V...
# Running Cyc215: Charge to 4.2V...
# Running Cyc215: Discharge to 3.0V...
# Running Cyc216: Charge to 4.2V...
# Running Cyc216: Discharge to 3.0V...
# Running Cyc217: Charge to 4.2V...
# Running Cyc217: Discharge to 3.0V...
# Running Cyc218: Charge to 4.2V...
# Running Cyc218: Discharge to 3.0V...
# Running Cyc219: Charge to 4.2V...
# Running Cyc219: Discharge to 3.0V...
# Running Cyc220: Charge to 4.2V...
# Running Cyc220: Discharge to 3.0V...
# Running Cyc221: Charge to 4.2V...
# Running Cyc221: Discharge to 3.0V...
# Running Cyc222: Charge to 4.2V...
# Running Cyc222: Discharge to 3.0V...
# Running Cyc223: Charge to 4.2V...
# Running Cyc223: Discharge to 3.0V...
# Running Cyc224: Charge to 4.2V...
# Running Cyc224: Discharge to 3.0V...
# Running Cyc225: Charge to 4.2V...
# Running Cyc225: Discharge to 3.0V...
# Running Cyc226: Charge to 4.2V...
# Running Cyc226: Discharge to 3.0V...
# Running Cyc227: Charge to 4.2V...
# Running Cyc227: Discharge to 3.0V...
# Running Cyc228: Charge to 4.2V...
# Running Cyc228: Discharge to 3.0V...
# Running Cyc229: Charge to 4.2V...
# Running Cyc229: Discharge to 3.0V...
# Running Cyc230: Charge to 4.2V...
# Running Cyc230: Discharge to 3.0V...
# Running Cyc231: Charge to 4.2V...
# Running Cyc231: Discharge to 3.0V...
# Running Cyc232: Charge to 4.2V...
# Running Cyc232: Discharge to 3.0V...
# Running Cyc233: Charge to 4.2V...
# Running Cyc233: Discharge to 3.0V...
# Running Cyc234: Charge to 4.2V...
# Running Cyc234: Discharge to 3.0V...
# Running Cyc235: Charge to 4.2V...
# Running Cyc235: Discharge to 3.0V...
# Running Cyc236: Charge to 4.2V...
# Running Cyc236: Discharge to 3.0V...
# Running Cyc237: Charge to 4.2V...
# Running Cyc237: Discharge to 3.0V...
# Running Cyc238: Charge to 4.2V...
# Running Cyc238: Discharge to 3.0V...
# Running Cyc239: Charge to 4.2V...
# Running Cyc239: Discharge to 3.0V...
# Running Cyc240: Charge to 4.2V...
# Running Cyc240: Discharge to 3.0V...
# Running Cyc241: Charge to 4.2V...
# Running Cyc241: Discharge to 3.0V...
# Running Cyc242: Charge to 4.2V...
# Running Cyc242: Discharge to 3.0V...
# Running Cyc243: Charge to 4.2V...
# Running Cyc243: Discharge to 3.0V...
# Running Cyc244: Charge to 4.2V...
# Running Cyc244: Discharge to 3.0V...
# Running Cyc245: Charge to 4.2V...
# Running Cyc245: Discharge to 3.0V...
# Running Cyc246: Charge to 4.2V...
# Running Cyc246: Discharge to 3.0V...
# Running Cyc247: Charge to 4.2V...
# Running Cyc247: Discharge to 3.0V...
# Running Cyc248: Charge to 4.2V...
# Running Cyc248: Discharge to 3.0V...
# Running Cyc249: Charge to 4.2V...
# Running Cyc249: Discharge to 3.0V...
# Running Cyc250: Charge to 4.2V...
# Running Cyc250: Discharge to 3.0V...
# Running Cyc251: Charge to 4.2V...
# Running Cyc251: Discharge to 3.0V...
# Running Cyc252: Charge to 4.2V...
# Running Cyc252: Discharge to 3.0V...
# Running Cyc253: Charge to 4.2V...
# Running Cyc253: Discharge to 3.0V...
# Running Cyc254: Charge to 4.2V...
# Running Cyc254: Discharge to 3.0V...
# Running Cyc255: Charge to 4.2V...
# Running Cyc255: Discharge to 3.0V...
# Running Cyc256: Charge to 4.2V...
# Running Cyc256: Discharge to 3.0V...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc7: Charge to 4.2V...
# Running Cyc7: Discharge to 3.0V...
# Running Cyc8: Charge to 4.2V...
# Running Cyc8: Discharge to 3.0V...
# Running Cyc9: Charge to 4.2V...
# Running Cyc9: Discharge to 3.0V...
# Running Cyc10: Charge to 4.2V...
# Running Cyc10: Discharge to 3.0V...
# Running Cyc11: Charge to 4.2V...
# Running Cyc11: Discharge to 3.0V...
# Running Cyc12: Charge to 4.2V...
# Running Cyc12: Discharge to 3.0V...
# Running Cyc13: Charge to 4.2V...
# Running Cyc13: Discharge to 3.0V...
# Running Cyc14: Charge to 4.2V...
# Running Cyc14: Discharge to 3.0V...
# Running Cyc15: Charge to 4.2V...
# Running Cyc15: Discharge to 3.0V...
# Running Cyc16: Charge to 4.2V...
# Running Cyc16: Discharge to 3.0V...
# Running Cyc17: Charge to 4.2V...
# Running Cyc17: Discharge to 3.0V...
# Running Cyc18: Charge to 4.2V...
# Running Cyc18: Discharge to 3.0V...
# Running Cyc19: Charge to 4.2V...
# Running Cyc19: Discharge to 3.0V...
# Running Cyc20: Charge to 4.2V...
# Running Cyc20: Discharge to 3.0V...
# Running Cyc21: Charge to 4.2V...
# Running Cyc21: Discharge to 3.0V...
# Running Cyc22: Charge to 4.2V...
# Running Cyc22: Discharge to 3.0V...
# Running Cyc23: Charge to 4.2V...
# Running Cyc23: Discharge to 3.0V...
# Running Cyc24: Charge to 4.2V...
# Running Cyc24: Discharge to 3.0V...
# Running Cyc25: Charge to 4.2V...
# Running Cyc25: Discharge to 3.0V...
# Running Cyc26: Charge to 4.2V...
# Running Cyc26: Discharge to 3.0V...
# Running Cyc27: Charge to 4.2V...
# Running Cyc27: Discharge to 3.0V...
# Running Cyc28: Charge to 4.2V...
# Running Cyc28: Discharge to 3.0V...
# Running Cyc29: Charge to 4.2V...
# Running Cyc29: Discharge to 3.0V...
# Running Cyc30: Charge to 4.2V...
# Running Cyc30: Discharge to 3.0V...
# Running Cyc31: Charge to 4.2V...
# Running Cyc31: Discharge to 3.0V...
# Running Cyc32: Charge to 4.2V...
# Running Cyc32: Discharge to 3.0V...
# Running Cyc33: Charge to 4.2V...
# Running Cyc33: Discharge to 3.0V...
# Running Cyc34: Charge to 4.2V...
# Running Cyc34: Discharge to 3.0V...
# Running Cyc35: Charge to 4.2V...
# Running Cyc35: Discharge to 3.0V...
# Running Cyc36: Charge to 4.2V...
# Running Cyc36: Discharge to 3.0V...
# Running Cyc37: Charge to 4.2V...
# Running Cyc37: Discharge to 3.0V...
# Running Cyc38: Charge to 4.2V...
# Running Cyc38: Discharge to 3.0V...
# Running Cyc39: Charge to 4.2V...
# Running Cyc39: Discharge to 3.0V...
# Running Cyc40: Charge to 4.2V...
# Running Cyc40: Discharge to 3.0V...
# Running Cyc41: Charge to 4.2V...
# Running Cyc41: Discharge to 3.0V...
# Running Cyc42: Charge to 4.2V...
# Running Cyc42: Discharge to 3.0V...
# Running Cyc43: Charge to 4.2V...
# Running Cyc43: Discharge to 3.0V...
# Running Cyc44: Charge to 4.2V...
# Running Cyc44: Discharge to 3.0V...
# Running Cyc45: Charge to 4.2V...
# Running Cyc45: Discharge to 3.0V...
# Running Cyc46: Charge to 4.2V...
# Running Cyc46: Discharge to 3.0V...
# Running Cyc47: Charge to 4.2V...
# Running Cyc47: Discharge to 3.0V...
# Running Cyc48: Charge to 4.2V...
# Running Cyc48: Discharge to 3.0V...
# Running Cyc49: Charge to 4.2V...
# Running Cyc49: Discharge to 3.0V...
# Running Cyc50: Charge to 4.2V...
# Running Cyc50: Discharge to 3.0V...
# Running Cyc51: Charge to 4.2V...
# Running Cyc51: Discharge to 3.0V...
# Running Cyc52: Charge to 4.2V...
# Running Cyc52: Discharge to 3.0V...
# Running Cyc53: Charge to 4.2V...
# Running Cyc53: Discharge to 3.0V...
# Running Cyc54: Charge to 4.2V...
# Running Cyc54: Discharge to 3.0V...
# Running Cyc55: Charge to 4.2V...
# Running Cyc55: Discharge to 3.0V...
# Running Cyc56: Charge to 4.2V...
# Running Cyc56: Discharge to 3.0V...
# Running Cyc57: Charge to 4.2V...
# Running Cyc57: Discharge to 3.0V...
# Running Cyc58: Charge to 4.2V...
# Running Cyc58: Discharge to 3.0V...
# Running Cyc59: Charge to 4.2V...
# Running Cyc59: Discharge to 3.0V...
# Running Cyc60: Charge to 4.2V...
# Running Cyc60: Discharge to 3.0V...
# Running Cyc61: Charge to 4.2V...
# Running Cyc61: Discharge to 3.0V...
# Running Cyc62: Charge to 4.2V...
# Running Cyc62: Discharge to 3.0V...
# Running Cyc63: Charge to 4.2V...
# Running Cyc63: Discharge to 3.0V...
# Running Cyc64: Charge to 4.2V...
# Running Cyc64: Discharge to 3.0V...
# Running Cyc65: Charge to 4.2V...
# Running Cyc65: Discharge to 3.0V...
# Running Cyc66: Charge to 4.2V...
# Running Cyc66: Discharge to 3.0V...
# Running Cyc67: Charge to 4.2V...
# Running Cyc67: Discharge to 3.0V...
# Running Cyc68: Charge to 4.2V...
# Running Cyc68: Discharge to 3.0V...
# Running Cyc69: Charge to 4.2V...
# Running Cyc69: Discharge to 3.0V...
# Running Cyc70: Charge to 4.2V...
# Running Cyc70: Discharge to 3.0V...
# Running Cyc71: Charge to 4.2V...
# Running Cyc71: Discharge to 3.0V...
# Running Cyc72: Charge to 4.2V...
# Running Cyc72: Discharge to 3.0V...
# Running Cyc73: Charge to 4.2V...
# Running Cyc73: Discharge to 3.0V...
# Running Cyc74: Charge to 4.2V...
# Running Cyc74: Discharge to 3.0V...
# Running Cyc75: Charge to 4.2V...
# Running Cyc75: Discharge to 3.0V...
# Running Cyc76: Charge to 4.2V...
# Running Cyc76: Discharge to 3.0V...
# Running Cyc77: Charge to 4.2V...
# Running Cyc77: Discharge to 3.0V...
# Running Cyc78: Charge to 4.2V...
# Running Cyc78: Discharge to 3.0V...
# Running Cyc79: Charge to 4.2V...
# Running Cyc79: Discharge to 3.0V...
# Running Cyc80: Charge to 4.2V...
# Running Cyc80: Discharge to 3.0V...
# Running Cyc81: Charge to 4.2V...
# Running Cyc81: Discharge to 3.0V...
# Running Cyc82: Charge to 4.2V...
# Running Cyc82: Discharge to 3.0V...
# Running Cyc83: Charge to 4.2V...
# Running Cyc83: Discharge to 3.0V...
# Running Cyc84: Charge to 4.2V...
# Running Cyc84: Discharge to 3.0V...
# Running Cyc85: Charge to 4.2V...
# Running Cyc85: Discharge to 3.0V...
# Running Cyc86: Charge to 4.2V...
# Running Cyc86: Discharge to 3.0V...
# Running Cyc87: Charge to 4.2V...
# Running Cyc87: Discharge to 3.0V...
# Running Cyc88: Charge to 4.2V...
# Running Cyc88: Discharge to 3.0V...
# Running Cyc89: Charge to 4.2V...
# Running Cyc89: Discharge to 3.0V...
# Running Cyc90: Charge to 4.2V...
# Running Cyc90: Discharge to 3.0V...
# Running Cyc91: Charge to 4.2V...
# Running Cyc91: Discharge to 3.0V...
# Running Cyc92: Charge to 4.2V...
# Running Cyc92: Discharge to 3.0V...
# Running Cyc93: Charge to 4.2V...
# Running Cyc93: Discharge to 3.0V...
# Running Cyc94: Charge to 4.2V...
# Running Cyc94: Discharge to 3.0V...
# Running Cyc95: Charge to 4.2V...
# Running Cyc95: Discharge to 3.0V...
# Running Cyc96: Charge to 4.2V...
# Running Cyc96: Discharge to 3.0V...
# Running Cyc97: Charge to 4.2V...
# Running Cyc97: Discharge to 3.0V...
# Running Cyc98: Charge to 4.2V...
# Running Cyc98: Discharge to 3.0V...
# Running Cyc99: Charge to 4.2V...
# Running Cyc99: Discharge to 3.0V...
# Running Cyc100: Charge to 4.2V...
# Running Cyc100: Discharge to 3.0V...
# Running Cyc101: Charge to 4.2V...
# Running Cyc101: Discharge to 3.0V...
# Running Cyc102: Charge to 4.2V...
# Running Cyc102: Discharge to 3.0V...
# Running Cyc103: Charge to 4.2V...
# Running Cyc103: Discharge to 3.0V...
# Running Cyc104: Charge to 4.2V...
# Running Cyc104: Discharge to 3.0V...
# Running Cyc105: Charge to 4.2V...
# Running Cyc105: Discharge to 3.0V...
# Running Cyc106: Charge to 4.2V...
# Running Cyc106: Discharge to 3.0V...
# Running Cyc107: Charge to 4.2V...
# Running Cyc107: Discharge to 3.0V...
# Running Cyc108: Charge to 4.2V...
# Running Cyc108: Discharge to 3.0V...
# Running Cyc109: Charge to 4.2V...
# Running Cyc109: Discharge to 3.0V...
# Running Cyc110: Charge to 4.2V...
# Running Cyc110: Discharge to 3.0V...
# Running Cyc111: Charge to 4.2V...
# Running Cyc111: Discharge to 3.0V...
# Running Cyc112: Charge to 4.2V...
# Running Cyc112: Discharge to 3.0V...
# Running Cyc113: Charge to 4.2V...
# Running Cyc113: Discharge to 3.0V...
# Running Cyc114: Charge to 4.2V...
# Running Cyc114: Discharge to 3.0V...
# Running Cyc115: Charge to 4.2V...
# Running Cyc115: Discharge to 3.0V...
# Running Cyc116: Charge to 4.2V...
# Running Cyc116: Discharge to 3.0V...
# Running Cyc117: Charge to 4.2V...
# Running Cyc117: Discharge to 3.0V...
# Running Cyc118: Charge to 4.2V...
# Running Cyc118: Discharge to 3.0V...
# Running Cyc119: Charge to 4.2V...
# Running Cyc119: Discharge to 3.0V...
# Running Cyc120: Charge to 4.2V...
# Running Cyc120: Discharge to 3.0V...
# Running Cyc121: Charge to 4.2V...
# Running Cyc121: Discharge to 3.0V...
# Running Cyc122: Charge to 4.2V...
# Running Cyc122: Discharge to 3.0V...
# Running Cyc123: Charge to 4.2V...
# Running Cyc123: Discharge to 3.0V...
# Running Cyc124: Charge to 4.2V...
# Running Cyc124: Discharge to 3.0V...
# Running Cyc125: Charge to 4.2V...
# Running Cyc125: Discharge to 3.0V...
# Running Cyc126: Charge to 4.2V...
# Running Cyc126: Discharge to 3.0V...
# Running Cyc127: Charge to 4.2V...
# Running Cyc127: Discharge to 3.0V...
# Running Cyc128: Charge to 4.2V...
# Running Cyc128: Discharge to 3.0V...
# Running Cyc129: Charge to 4.2V...
# Running Cyc129: Discharge to 3.0V...
# Running Cyc130: Charge to 4.2V...
# Running Cyc130: Discharge to 3.0V...
# Running Cyc131: Charge to 4.2V...
# Running Cyc131: Discharge to 3.0V...
# Running Cyc132: Charge to 4.2V...
# Running Cyc132: Discharge to 3.0V...
# Running Cyc133: Charge to 4.2V...
# Running Cyc133: Discharge to 3.0V...
# Running Cyc134: Charge to 4.2V...
# Running Cyc134: Discharge to 3.0V...
# Running Cyc135: Charge to 4.2V...
# Running Cyc135: Discharge to 3.0V...
# Running Cyc136: Charge to 4.2V...
# Running Cyc136: Discharge to 3.0V...
# Running Cyc137: Charge to 4.2V...
# Running Cyc137: Discharge to 3.0V...
# Running Cyc138: Charge to 4.2V...
# Running Cyc138: Discharge to 3.0V...
# Running Cyc139: Charge to 4.2V...
# Running Cyc139: Discharge to 3.0V...
# Running Cyc140: Charge to 4.2V...
# Running Cyc140: Discharge to 3.0V...
# Running Cyc141: Charge to 4.2V...
# Running Cyc141: Discharge to 3.0V...
# Running Cyc142: Charge to 4.2V...
# Running Cyc142: Discharge to 3.0V...
# Running Cyc143: Charge to 4.2V...
# Running Cyc143: Discharge to 3.0V...
# Running Cyc144: Charge to 4.2V...
# Running Cyc144: Discharge to 3.0V...
# Running Cyc145: Charge to 4.2V...
# Running Cyc145: Discharge to 3.0V...
# Running Cyc146: Charge to 4.2V...
# Running Cyc146: Discharge to 3.0V...
# Running Cyc147: Charge to 4.2V...
# Running Cyc147: Discharge to 3.0V...
# Running Cyc148: Charge to 4.2V...
# Running Cyc148: Discharge to 3.0V...
# Running Cyc149: Charge to 4.2V...
# Running Cyc149: Discharge to 3.0V...
# Running Cyc150: Charge to 4.2V...
# Running Cyc150: Discharge to 3.0V...
# Running Cyc151: Charge to 4.2V...
# Running Cyc151: Discharge to 3.0V...
# Running Cyc152: Charge to 4.2V...
# Running Cyc152: Discharge to 3.0V...
# Running Cyc153: Charge to 4.2V...
# Running Cyc153: Discharge to 3.0V...
# Running Cyc154: Charge to 4.2V...
# Running Cyc154: Discharge to 3.0V...
# Running Cyc155: Charge to 4.2V...
# Running Cyc155: Discharge to 3.0V...
# Running Cyc156: Charge to 4.2V...
# Running Cyc156: Discharge to 3.0V...
# Running Cyc157: Charge to 4.2V...
# Running Cyc157: Discharge to 3.0V...
# Running Cyc158: Charge to 4.2V...
# Running Cyc158: Discharge to 3.0V...
# Running Cyc159: Charge to 4.2V...
# Running Cyc159: Discharge to 3.0V...
# Running Cyc160: Charge to 4.2V...
# Running Cyc160: Discharge to 3.0V...
# Running Cyc161: Charge to 4.2V...
# Running Cyc161: Discharge to 3.0V...
# Running Cyc162: Charge to 4.2V...
# Running Cyc162: Discharge to 3.0V...
# Running Cyc163: Charge to 4.2V...
# Running Cyc163: Discharge to 3.0V...
# Running Cyc164: Charge to 4.2V...
# Running Cyc164: Discharge to 3.0V...
# Running Cyc165: Charge to 4.2V...
# Running Cyc165: Discharge to 3.0V...
# Running Cyc166: Charge to 4.2V...
# Running Cyc166: Discharge to 3.0V...
# Running Cyc167: Charge to 4.2V...
# Running Cyc167: Discharge to 3.0V...
# Running Cyc168: Charge to 4.2V...
# Running Cyc168: Discharge to 3.0V...
# Running Cyc169: Charge to 4.2V...
# Running Cyc169: Discharge to 3.0V...
# Running Cyc170: Charge to 4.2V...
# Running Cyc170: Discharge to 3.0V...
# Running Cyc171: Charge to 4.2V...
# Running Cyc171: Discharge to 3.0V...
# Running Cyc172: Charge to 4.2V...
# Running Cyc172: Discharge to 3.0V...
# Running Cyc173: Charge to 4.2V...
# Running Cyc173: Discharge to 3.0V...
# Running Cyc174: Charge to 4.2V...
# Running Cyc174: Discharge to 3.0V...
# Running Cyc175: Charge to 4.2V...
# Running Cyc175: Discharge to 3.0V...
# Running Cyc176: Charge to 4.2V...
# Running Cyc176: Discharge to 3.0V...
# Running Cyc177: Charge to 4.2V...
# Running Cyc177: Discharge to 3.0V...
# Running Cyc178: Charge to 4.2V...
# Running Cyc178: Discharge to 3.0V...
# Running Cyc179: Charge to 4.2V...
# Running Cyc179: Discharge to 3.0V...
# Running Cyc180: Charge to 4.2V...
# Running Cyc180: Discharge to 3.0V...
# Running Cyc181: Charge to 4.2V...
# Running Cyc181: Discharge to 3.0V...
# Running Cyc182: Charge to 4.2V...
# Running Cyc182: Discharge to 3.0V...
# Running Cyc183: Charge to 4.2V...
# Running Cyc183: Discharge to 3.0V...
# Running Cyc184: Charge to 4.2V...
# Running Cyc184: Discharge to 3.0V...
# Running Cyc185: Charge to 4.2V...
# Running Cyc185: Discharge to 3.0V...
# Running Cyc186: Charge to 4.2V...
# Running Cyc186: Discharge to 3.0V...
# Running Cyc187: Charge to 4.2V...
# Running Cyc187: Discharge to 3.0V...
# Running Cyc188: Charge to 4.2V...
# Running Cyc188: Discharge to 3.0V...
# Running Cyc189: Charge to 4.2V...
# Running Cyc189: Discharge to 3.0V...
# Running Cyc190: Charge to 4.2V...
# Running Cyc190: Discharge to 3.0V...
# Running Cyc191: Charge to 4.2V...
# Running Cyc191: Discharge to 3.0V...
# Running Cyc192: Charge to 4.2V...
# Running Cyc192: Discharge to 3.0V...
# Running Cyc193: Charge to 4.2V...
# Running Cyc193: Discharge to 3.0V...
# Running Cyc194: Charge to 4.2V...
# Running Cyc194: Discharge to 3.0V...
# Running Cyc195: Charge to 4.2V...
# Running Cyc195: Discharge to 3.0V...
# Running Cyc196: Charge to 4.2V...
# Running Cyc196: Discharge to 3.0V...
# Running Cyc197: Charge to 4.2V...
# Running Cyc197: Discharge to 3.0V...
# Running Cyc198: Charge to 4.2V...
# Running Cyc198: Discharge to 3.0V...
# Running Cyc199: Charge to 4.2V...
# Running Cyc199: Discharge to 3.0V...
# Running Cyc200: Charge to 4.2V...
# Running Cyc200: Discharge to 3.0V...
# Running Cyc201: Charge to 4.2V...
# Running Cyc201: Discharge to 3.0V...
# Running Cyc202: Charge to 4.2V...
# Running Cyc202: Discharge to 3.0V...
# Running Cyc203: Charge to 4.2V...
# Running Cyc203: Discharge to 3.0V...
# Running Cyc204: Charge to 4.2V...
# Running Cyc204: Discharge to 3.0V...
# Running Cyc205: Charge to 4.2V...
# Running Cyc205: Discharge to 3.0V...
# Running Cyc206: Charge to 4.2V...
# Running Cyc206: Discharge to 3.0V...
# Running Cyc207: Charge to 4.2V...
# Running Cyc207: Discharge to 3.0V...
# Running Cyc208: Charge to 4.2V...
# Running Cyc208: Discharge to 3.0V...
# Running Cyc209: Charge to 4.2V...
# Running Cyc209: Discharge to 3.0V...
# Running Cyc210: Charge to 4.2V...
# Running Cyc210: Discharge to 3.0V...
# Running Cyc211: Charge to 4.2V...
# Running Cyc211: Discharge to 3.0V...
# Running Cyc212: Charge to 4.2V...
# Running Cyc212: Discharge to 3.0V...
# Running Cyc213: Charge to 4.2V...
# Running Cyc213: Discharge to 3.0V...
# Running Cyc214: Charge to 4.2V...
# Running Cyc214: Discharge to 3.0V...
# Running Cyc215: Charge to 4.2V...
# Running Cyc215: Discharge to 3.0V...
# Running Cyc216: Charge to 4.2V...
# Running Cyc216: Discharge to 3.0V...
# Running Cyc217: Charge to 4.2V...
# Running Cyc217: Discharge to 3.0V...
# Running Cyc218: Charge to 4.2V...
# Running Cyc218: Discharge to 3.0V...
# Running Cyc219: Charge to 4.2V...
# Running Cyc219: Discharge to 3.0V...
# Running Cyc220: Charge to 4.2V...
# Running Cyc220: Discharge to 3.0V...
# Running Cyc221: Charge to 4.2V...
# Running Cyc221: Discharge to 3.0V...
# Running Cyc222: Charge to 4.2V...
# Running Cyc222: Discharge to 3.0V...
# Running Cyc223: Charge to 4.2V...
# Running Cyc223: Discharge to 3.0V...
# Running Cyc224: Charge to 4.2V...
# Running Cyc224: Discharge to 3.0V...
# Running Cyc225: Charge to 4.2V...
# Running Cyc225: Discharge to 3.0V...
# Running Cyc226: Charge to 4.2V...
# Running Cyc226: Discharge to 3.0V...
# Running Cyc227: Charge to 4.2V...
# Running Cyc227: Discharge to 3.0V...
# Running Cyc228: Charge to 4.2V...
# Running Cyc228: Discharge to 3.0V...
# Running Cyc229: Charge to 4.2V...
# Running Cyc229: Discharge to 3.0V...
# Running Cyc230: Charge to 4.2V...
# Running Cyc230: Discharge to 3.0V...
# Running Cyc231: Charge to 4.2V...
# Running Cyc231: Discharge to 3.0V...
# Running Cyc232: Charge to 4.2V...
# Running Cyc232: Discharge to 3.0V...
# Running Cyc233: Charge to 4.2V...
# Running Cyc233: Discharge to 3.0V...
# Running Cyc234: Charge to 4.2V...
# Running Cyc234: Discharge to 3.0V...
# Running Cyc235: Charge to 4.2V...
# Running Cyc235: Discharge to 3.0V...
# Running Cyc236: Charge to 4.2V...
# Running Cyc236: Discharge to 3.0V...
# Running Cyc237: Charge to 4.2V...
# Running Cyc237: Discharge to 3.0V...
# Running Cyc238: Charge to 4.2V...
# Running Cyc238: Discharge to 3.0V...
# Running Cyc239: Charge to 4.2V...
# Running Cyc239: Discharge to 3.0V...
# Running Cyc240: Charge to 4.2V...
# Running Cyc240: Discharge to 3.0V...
# Running Cyc241: Charge to 4.2V...
# Running Cyc241: Discharge to 3.0V...
# Running Cyc242: Charge to 4.2V...
# Running Cyc242: Discharge to 3.0V...
# Running Cyc243: Charge to 4.2V...
# Running Cyc243: Discharge to 3.0V...
# Running Cyc244: Charge to 4.2V...
# Running Cyc244: Discharge to 3.0V...
# Running Cyc245: Charge to 4.2V...
# Running Cyc245: Discharge to 3.0V...
# Running Cyc246: Charge to 4.2V...
# Running Cyc246: Discharge to 3.0V...
# Running Cyc247: Charge to 4.2V...
# Running Cyc247: Discharge to 3.0V...
# Running Cyc248: Charge to 4.2V...
# Running Cyc248: Discharge to 3.0V...
# Running Cyc249: Charge to 4.2V...
# Running Cyc249: Discharge to 3.0V...
# Running Cyc250: Charge to 4.2V...
# Running Cyc250: Discharge to 3.0V...
# Running Cyc251: Charge to 4.2V...
# Running Cyc251: Discharge to 3.0V...
# Running Cyc252: Charge to 4.2V...
# Running Cyc252: Discharge to 3.0V...
# Running Cyc253: Charge to 4.2V...
# Running Cyc253: Discharge to 3.0V...
# Running Cyc254: Charge to 4.2V...
# Running Cyc254: Discharge to 3.0V...
# Running Cyc255: Charge to 4.2V...
# Running Cyc255: Discharge to 3.0V...
# Running Cyc256: Charge to 4.2V...
# Running Cyc256: Discharge to 3.0V...

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_sim1['t'] / 3600, df_sim1['vt'], label='Base Formation')
plt.plot(df_sim2['t'] / 3600, df_sim2['vt'], label='Fast Formation')
plt.plot(df_sim3['t'] / 3600, df_sim3['vt'], label='Fast+ Formation')
plt.xlabel('Time (hours)')
plt.ylabel('Voltage (V)')
plt.title('Voltage vs. Time for Different Formation Protocols')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
idx_first_cycle_count_base = 5
idx_first_cycle_count_fast = 7
idx_first_cycle_count_fast_plus = 7

# Aggregate results by cycle number, step number, then sum the dq
df1_group = df_sim1.groupby(['cycle_number', 'step_number']).agg({'dq': 'sum', 'c_sei2' : 'max', 'R_sei' : 'max'})
df2_group = df_sim2.groupby(['cycle_number', 'step_number']).agg({'dq': 'sum', 'c_sei2' : 'max', 'R_sei' : 'max'})
df3_group = df_sim3.groupby(['cycle_number', 'step_number']).agg({'dq': 'sum', 'c_sei2' : 'max', 'R_sei' : 'max'})

# Filter for step_number==2, the discharge steps
df1_group_filtered = df1_group.loc[df1_group.index.get_level_values('step_number') == 2]
df2_group_filtered = df2_group.loc[df2_group.index.get_level_values('step_number') == 2]
df3_group_filtered = df3_group.loc[df3_group.index.get_level_values('step_number') == 2]

fig, axs = plt.subplots(3, 1, figsize=(8, 8), sharex=True)
[ax.grid(False) for ax in axs]

axs[0].plot(df1_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_base,
         df1_group_filtered['dq'], c='k', label='Baseline')

axs[0].plot(df2_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_fast,
         df2_group_filtered['dq'], c='r', label='Fast')

axs[0].plot(df3_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_fast_plus,
         df3_group_filtered['dq'], c='b', label='Fast+')

axs[0].set_ylabel('Discharge Capacity [Ah]')
axs[0].legend()

axs[1].plot(df1_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_base,
         df1_group_filtered['c_sei2'], c='k', label='Baseline')

axs[1].plot(df2_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_fast,
         df2_group_filtered['c_sei2'], c='r', label='Fast')

axs[1].plot(df3_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_fast_plus,
         df3_group_filtered['c_sei2'], c='b', label='Fast+')

axs[1].set_ylabel('$c_\mathrm{VC}$ [mol/m$^3$]')
axs[1].legend()

axs[2].plot(df1_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_base,
         df1_group_filtered['R_sei'] + 0.01 + 0.0085 * 2, c='k', label='Baseline')

axs[2].plot(df2_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_fast,
         df2_group_filtered['R_sei'] + 0.01 + 0.0085 * 2, c='r', label='Fast')

axs[2].plot(df3_group_filtered.index.get_level_values('cycle_number').values - idx_first_cycle_count_fast_plus,
         df3_group_filtered['R_sei'] + 0.01 + 0.0085 * 2, c='b', label='Fast+')

axs[2].set_xlabel('Cycle Number')
axs[2].set_ylabel('$R_\mathrm{SEI}$ [$\Omega$]')
axs[2].legend()

axs[2].set_xlim((0, 250))

plt.show()
plt.legend()
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\m'
# <>:52: SyntaxWarning: invalid escape sequence '\m'
# <>:39: SyntaxWarning: invalid escape sequence '\m'
# <>:52: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/235498587.py:39: SyntaxWarning: invalid escape sequence '\m'
#   axs[1].set_ylabel('$c_\mathrm{VC}$ [mol/m$^3$]')
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_19256/235498587.py:52: SyntaxWarning: invalid escape sequence '\m'
#   axs[2].set_ylabel('$R_\mathrm{SEI}$ [$\Omega$]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
XLIM = (0, 30)
# Beware of experimental vs model data indexing!!
rmse1_v, tv1, sv1 = calculate_rmse(expt1['arbin_time'], expt1['arbin_voltage'], df_sim1['t'], df_sim1['vt'], y_range=(3.0, 4.5))
rmse1t_v, tv1t, sv1t = calculate_rmse(expt1['arbin_time'], expt1['arbin_voltage'], df_sim1_timesync['t'], df_sim1_timesync['vt'], y_range=(3.0, 4.5))
rmse1_e, te1, se1 = calculate_rmse(expt1['daq_time'], expt1['daq_strain'], df_sim1['t'], df_sim1['expansion']*1e6)
rmse1t_e, te1t, se1t = calculate_rmse(expt1['daq_time'], expt1['daq_strain'], df_sim1_timesync['t'], df_sim1_timesync['expansion']*1e6)

rmse2_v, tv2, sv2 = calculate_rmse(expt3['arbin_time'], expt3['arbin_voltage'], df_sim2['t'], df_sim2['vt'], y_range=(3.0, 4.5))
rmse2t_v, tv2t, sv2t = calculate_rmse(expt3['arbin_time'], expt3['arbin_voltage'], df_sim2_timesync['t'], df_sim2_timesync['vt'], y_range=(3.0, 4.5))
rmse2_e, te2, se2 = calculate_rmse(expt3['daq_time'], expt3['daq_strain'], df_sim2['t'], df_sim2['expansion']*1e6)
rmse2t_e, te2t, se2t = calculate_rmse(expt3['daq_time'], expt3['daq_strain'], df_sim2_timesync['t'], df_sim2_timesync['expansion']*1e6)

rmse3_v, tv3, sv3 = calculate_rmse(expt4['arbin_time'], expt4['arbin_voltage'], df_sim3['t'], df_sim3['vt'], y_range=(3.0, 4.5))
rmse3t_v, tv3t, sv3t = calculate_rmse(expt4['arbin_time'], expt4['arbin_voltage'], df_sim3_timesync['t'], df_sim3_timesync['vt'], y_range=(3.0, 4.5))
rmse3_e, te3, se3 = calculate_rmse(expt4['daq_time'], expt4['daq_strain'], df_sim3['t'], df_sim3['expansion']*1e6)
rmse3t_e, te3t, se3t = calculate_rmse(expt4['daq_time'], expt4['daq_strain'], df_sim3_timesync['t'], df_sim3_timesync['expansion']*1e6)

fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# Voltage plot
ax = axes[0, 0]
ax.plot(expt1['arbin_time']/3600, expt1['arbin_voltage'], color='k', label=f'Base, RMSE = {rmse1_v:.2f} V')
ax.plot(expt3['arbin_time']/3600, expt3['arbin_voltage'], color='b', label=f'Fast, RMSE = {rmse2_v:.2f} V')
ax.plot(expt4['arbin_time']/3600, expt4['arbin_voltage'], color='r', label=f'Fast+, RMSE = {rmse3_v:.2f} V')
ax.plot(df_sim1['t']/3600, df_sim1['vt'], color='k', ls='--', label='')
ax.plot(df_sim2['t']/3600, df_sim2['vt'], color='b', ls='--', label='')
ax.plot(df_sim3['t']/3600, df_sim3['vt'], color='r', ls='--', label='')
ax.plot(df_sim1_timesync['t']/3600, df_sim1_timesync['vt'], color='k', ls=':', label='')
ax.plot(df_sim2_timesync['t']/3600, df_sim2_timesync['vt'], color='b', ls=':', label='')
ax.plot(df_sim3_timesync['t']/3600, df_sim3_timesync['vt'], color='r', ls=':', label='')
ax.set_xlabel('Time (hrs)')
ax.set_ylabel('Voltage (V)')
ax.set_ylim(bottom=0)
ax.set_xlim(XLIM)
ax.legend(fontsize=10)
ax.grid(False)

# Voltage error plot
ax = axes[0, 1]
ax.plot(tv1/3600, sv1, color='k', label=f'Base, RMSE1 = {rmse1_v:.2f} V')
ax.plot(tv1t/3600, sv1t, color='k', ls=':', label=f'Base, RMSE2 = {rmse1t_v:.2f} V')
ax.plot(tv2/3600, sv2, color='b', label=f'Fast, RMSE1 = {rmse2_v:.2f} V')
ax.plot(tv2t/3600, sv2t, color='b', ls=':', label=f'Fast, RMSE2 = {rmse2t_v:.2f} V')
ax.plot(tv3/3600, sv3, color='r', label=f'Fast+, RMSE1 = {rmse3_v:.2f} V')
ax.plot(tv3t/3600, sv3t, color='r', ls=':', label=f'Fast+, RMSE2 = {rmse3t_v:.2f} V')
ax.set_xlabel('Time (hrs)')
ax.set_ylabel('Abs V Err (V)')
ax.set_xlim(XLIM)
ax.legend(fontsize=10)
ax.grid(False)

# Expansion plot
ax = axes[1, 0]
ax.plot(expt1['daq_time']/3600, expt1['daq_strain'], color='k', label=f'Base, RMSE = {rmse1_e:.2f} um')
ax.plot(expt3['daq_time']/3600, expt3['daq_strain'], color='b', label=f'Fast, RMSE = {rmse2_e:.2f} um')
ax.plot(expt4['daq_time']/3600, expt4['daq_strain'], color='r', label=f'Fast+, RMSE = {rmse3_e:.2f} um')
ax.plot(df_sim1['t']/3600, (df_sim1['expansion'])*1e6, color='k', ls='--', label='')
ax.plot(df_sim2['t']/3600, (df_sim2['expansion'])*1e6, color='b', ls='--', label='')
ax.plot(df_sim3['t']/3600, (df_sim3['expansion'])*1e6, color='r', ls='--', label='')
ax.plot(df_sim1_timesync['t']/3600, (df_sim1_timesync['expansion'])*1e6, color='k', ls=':', label='')
ax.plot(df_sim2_timesync['t']/3600, (df_sim2_timesync['expansion'])*1e6, color='b', ls=':', label='')
ax.plot(df_sim3_timesync['t']/3600, (df_sim3_timesync['expansion'])*1e6, color='r', ls=':', label='')
ax.legend(fontsize=10)
ax.set_ylabel(r'Expansion ($\mu$m)')
ax.set_ylim(bottom=0, top=150)
ax.set_xlabel('Time (hrs)')
ax.set_xlim(XLIM)
ax.grid(False)

# Expansion error plot
ax = axes[1, 1]
ax.plot(te1/3600, se1, color='k', label=f'Base, RMSE = {rmse1_e:.2f} um')
ax.plot(te2/3600, se2, color='b', label=f'Fast, RMSE = {rmse2_e:.2f} um')
ax.plot(te3/3600, se3, color='r', label=f'Fast+, RMSE = {rmse3_e:.2f} um')
ax.plot(te1t/3600, se1t, color='k', ls=':', label='')
ax.plot(te2t/3600, se2t, color='b', ls=':', label='')
ax.plot(te3t/3600, se3t, color='r', ls=':', label='')
ax.set_xlabel('Time (hrs)')
ax.set_ylabel(r'Abs Strain Err ($\mu$m)')
ax.set_ylim(bottom=0)
ax.set_xlim(XLIM)
ax.legend(fontsize=10)
ax.grid(False)

# Current plot
ax = axes[2, 0]
ax.plot(expt1['arbin_time']/3600, expt1['arbin_current'], color='k', label='Base')
ax.plot(expt3['arbin_time']/3600, expt3['arbin_current'], color='b', label='Fast')
ax.plot(expt4['arbin_time']/3600, expt4['arbin_current'], color='r', label='Fast+')
ax.plot(df_sim1['t']/3600, df_sim1['i_app'], color='k', ls='--', label='')
ax.plot(df_sim2['t']/3600, df_sim2['i_app'], color='b', ls='--', label='')
ax.plot(df_sim3['t']/3600, df_sim3['i_app'], color='r', ls='--', label='')
ax.plot(df_sim1_timesync['t']/3600, df_sim1_timesync['i_app'], color='k', ls=':', label='')
ax.plot(df_sim2_timesync['t']/3600, df_sim2_timesync['i_app'], color='k', ls=':', label='')
ax.plot(df_sim3_timesync['t']/3600, df_sim3_timesync['i_app'], color='k', ls=':', label='')
ax.set_xlabel('Time (hrs)')
ax.set_ylabel('Current (A)')
ax.legend(fontsize=10)
ax.grid(False)
ax.set_xlim(XLIM)

# Empty plot for alignment
axes[2, 1].axis('off')

# Link all x-axes
for i in range(3):
    for j in range(2):
        if i > 0 or j > 0:
            axes[i, j].sharex(axes[0, 0])

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Search for the optimal KAPPA_GAMMA parameter to use for tuning Rsei calculation

# %%
diff_ec = 4.2e-20
diff_vc = 6.6e-18 # For VC

nn = 50
gamma_kappa_vec = np.linspace(0, 5000, nn)

rmse1_e_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
rmse1_v_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
rmse2_e_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
rmse2_v_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
rmse3_e_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
rmse3_v_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
qsei1_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
qsei2_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
qsei3_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
qsei1_vc_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
qsei2_vc_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
qsei3_vc_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
expan1_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
expan2_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
expan3_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
resistance1_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
resistance2_mat = np.zeros((len(gamma_kappa_vec), 1)) * np.nan
resistance3_mat = np.zeros((len(gamma_kappa_vec), 1))

for i, gamma_kappa in enumerate(gamma_kappa_vec):

    print(f'Running simulation with gamma_kappa = {gamma_kappa:.2f}')

    try:
        # df_sim1 = run_sim('base', diff_ec, diff_vc, gamma_kappa)
        # df_sim2 = run_sim('fast', diff_ec, diff_vc, gamma_kappa)
        # df_sim3 = run_sim('fast+', diff_ec, diff_vc, gamma_kappa)
        df_sim1 = run_sim('base', diff_ec, diff_vc, gamma_kappa=gamma_kappa, dt=5.0, to_follow_current=True, current_vec=i_interp1)
        df_sim2 = run_sim('fast', diff_ec, diff_vc, gamma_kappa=gamma_kappa, dt=5.0, to_follow_current=True, current_vec=i_interp3)
        df_sim3 = run_sim('fast+', diff_ec, diff_vc, gamma_kappa=gamma_kappa, dt=5.0, to_follow_current=True, current_vec=i_interp4)
    except:
        continue

    # Extract the qsei values:
    qsei1_mat[i, 0] = df_sim1['q_sei'].iloc[-1]
    qsei2_mat[i, 0] = df_sim2['q_sei'].iloc[-1]
    qsei3_mat[i, 0] = df_sim3['q_sei'].iloc[-1]

    qsei1_vc_mat[i, 0] = df_sim1['q_sei2'].iloc[-1]
    qsei2_vc_mat[i, 0] = df_sim2['q_sei2'].iloc[-1]
    qsei3_vc_mat[i, 0] = df_sim3['q_sei2'].iloc[-1]

    # Extract the expansion values:
    expan1_mat[i, 0] = df_sim1['expansion'].iloc[-1]
    expan2_mat[i, 0] = df_sim2['expansion'].iloc[-1]
    expan3_mat[i, 0] = df_sim3['expansion'].iloc[-1]

    # Extract the resistance values:
    resistance1_mat[i, 0] = df_sim1['R_sei'].iloc[-1]
    resistance2_mat[i, 0] = df_sim2['R_sei'].iloc[-1]
    resistance3_mat[i, 0] = df_sim3['R_sei'].iloc[-1]

    # Beware of experimental vs model data indexing!!
    rmse1_v, _, _ = calculate_rmse(expt1['arbin_time'], expt1['arbin_voltage'], df_sim1['t'], df_sim1['vt'], y_range=(3.0, 4.5))
    rmse1_e, _, _ = calculate_rmse(expt1['daq_time'],   expt1['daq_strain'], df_sim1['t'], df_sim1['expansion']*1e6)
    rmse2_v, _, _ = calculate_rmse(expt3['arbin_time'], expt3['arbin_voltage'], df_sim2['t'], df_sim2['vt'], y_range=(3.0, 4.5))
    rmse2_e, _, _ = calculate_rmse(expt3['daq_time'],   expt3['daq_strain'], df_sim2['t'], df_sim2['expansion']*1e6)
    rmse3_v, _, _ = calculate_rmse(expt4['arbin_time'], expt4['arbin_voltage'], df_sim3['t'], df_sim3['vt'], y_range=(3.0, 4.5))
    rmse3_e, _, _ = calculate_rmse(expt4['daq_time'],   expt4['daq_strain'], df_sim3['t'], df_sim3['expansion']*1e6)

    rmse1_e_mat[i, 0] = rmse1_e
    rmse1_v_mat[i, 0] = rmse1_v
    rmse2_e_mat[i, 0] = rmse2_e
    rmse2_v_mat[i, 0] = rmse2_v
    rmse3_e_mat[i, 0] = rmse3_e
    rmse3_v_mat[i, 0] = rmse3_v
# Out:
# Running simulation with gamma_kappa = 0.00
# Running simulation with gamma_kappa = 102.04
# /Users/ampere/code/formation-modeling/src/cellsim.py:156: RuntimeWarning: divide by zero encountered in scalar divide
#   self.delta_sei1[0] /
# /Users/ampere/code/formation-modeling/src/cellsim.py:161: RuntimeWarning: divide by zero encountered in scalar divide
#   self.delta_sei2[0] /
# /Users/ampere/code/formation-modeling/src/cellsim.py:229: RuntimeWarning: invalid value encountered in scalar multiply
#   self.eta_n[k+1] = p.R1n * self.i_r1n[k] + self.R_sei[k] * self.i_int[k]
# Running simulation with gamma_kappa = 204.08
# Running simulation with gamma_kappa = 306.12
# Running simulation with gamma_kappa = 408.16
# Running simulation with gamma_kappa = 510.20
# Running simulation with gamma_kappa = 612.24
# Running simulation with gamma_kappa = 714.29
# Running simulation with gamma_kappa = 816.33
# Running simulation with gamma_kappa = 918.37
# Running simulation with gamma_kappa = 1020.41
# Running simulation with gamma_kappa = 1122.45
# Running simulation with gamma_kappa = 1224.49
# Running simulation with gamma_kappa = 1326.53
# Running simulation with gamma_kappa = 1428.57
# Running simulation with gamma_kappa = 1530.61
# Running simulation with gamma_kappa = 1632.65
# Running simulation with gamma_kappa = 1734.69
# Running simulation with gamma_kappa = 1836.73
# Running simulation with gamma_kappa = 1938.78
# Running simulation with gamma_kappa = 2040.82
# Running simulation with gamma_kappa = 2142.86
# Running simulation with gamma_kappa = 2244.90
# Running simulation with gamma_kappa = 2346.94
# Running simulation with gamma_kappa = 2448.98
# Running simulation with gamma_kappa = 2551.02
# Running simulation with gamma_kappa = 2653.06
# Running simulation with gamma_kappa = 2755.10
# Running simulation with gamma_kappa = 2857.14
# Running simulation with gamma_kappa = 2959.18
# Running simulation with gamma_kappa = 3061.22
# Running simulation with gamma_kappa = 3163.27
# Running simulation with gamma_kappa = 3265.31
# Running simulation with gamma_kappa = 3367.35
# Running simulation with gamma_kappa = 3469.39
# Running simulation with gamma_kappa = 3571.43
# Running simulation with gamma_kappa = 3673.47
# Running simulation with gamma_kappa = 3775.51
# Running simulation with gamma_kappa = 3877.55
# Running simulation with gamma_kappa = 3979.59
# Running simulation with gamma_kappa = 4081.63
# Running simulation with gamma_kappa = 4183.67
# Running simulation with gamma_kappa = 4285.71
# Running simulation with gamma_kappa = 4387.76
# Running simulation with gamma_kappa = 4489.80
# Running simulation with gamma_kappa = 4591.84
# Running simulation with gamma_kappa = 4693.88
# Running simulation with gamma_kappa = 4795.92
# Running simulation with gamma_kappa = 4897.96
# Running simulation with gamma_kappa = 5000.00

# %%
rmse1_v_mat = rmse1_v_mat.flatten()
rmse1_e_mat = rmse1_e_mat.flatten()
rmse2_v_mat = rmse2_v_mat.flatten()
rmse2_e_mat = rmse2_e_mat.flatten()
rmse3_v_mat = rmse3_v_mat.flatten()
rmse3_e_mat = rmse3_e_mat.flatten()

rmse = (rmse1_v_mat + rmse2_v_mat + rmse3_v_mat)/3

plt.figure(figsize=(8, 6))
plt.plot(gamma_kappa_vec, rmse1_v_mat, label='Base', marker='o', c='r')
plt.plot(gamma_kappa_vec, rmse2_v_mat, label='Fast', marker='s', c='b')
plt.plot(gamma_kappa_vec, rmse3_v_mat, label='Fast+', marker='^', c='g')
plt.plot(gamma_kappa_vec, rmse, label=f'Average (Min at Gamma Kappa = {gamma_kappa_vec[np.nanargmin(rmse)]:.2f})', marker='<', c='k')
plt.plot(gamma_kappa_vec[np.nanargmin(rmse1_v_mat)], np.nanmin(rmse1_v_mat), 'ro', markersize=20, label='Base Min')
plt.plot(gamma_kappa_vec[np.nanargmin(rmse2_v_mat)], np.nanmin(rmse2_v_mat), 'bs', markersize=20, label='Fast Min')
plt.plot(gamma_kappa_vec[np.nanargmin(rmse3_v_mat)], np.nanmin(rmse3_v_mat), 'g^', markersize=20, label='Fast+ Min')
plt.plot(gamma_kappa_vec[np.nanargmin(rmse)], np.nanmin(rmse), 'k<', markersize=20, label='Average Min')
plt.xlabel('Gamma Kappa')
plt.ylabel('RMSE Voltage (V)')
plt.title('RMSE Voltage vs Gamma Kappa')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(df_sim1['q_sei'].iloc[-1])
print(df_sim2['q_sei'].iloc[-1])
print(df_sim3['q_sei'].iloc[-1])
# Out:
# 0.3307632315647437
# 0.266420151094688
# 0.2563235811629999

# %%
print(df_sim1['R_sei'].iloc[-1])
# Out:
# 0.018354808757535264

# %%
plt.figure(figsize=(10,5))
ax4 = plt.gca()
ax4.plot(df_sim1['t']/3600, df_sim1['delta_sei1']*1e9, color='k', ls='--', label='Base (EC)')
ax4.plot(df_sim2['t']/3600, df_sim2['delta_sei1']*1e9, ls='--', color='b', label='Fast (EC)')
ax4.plot(df_sim3['t']/3600, df_sim3['delta_sei1']*1e9, ls='--', color='r', label='Fast+ (EC)')
ax4.plot(df_sim1['t']/3600, (df_sim1['delta_sei'])*1e9, color='k', ls='-', label='Base (EC+VC)')
ax4.plot(df_sim2['t']/3600, (df_sim2['delta_sei'])*1e9, color='b', ls='-', label='Fast (EC+VC)')
ax4.plot(df_sim3['t']/3600, (df_sim3['delta_sei'])*1e9, color='r', ls='-', label='Fast+ (EC+VC)')
ax4.legend()
ax4.set_ylabel('SEI Thickness (nm)')
ax4.set_xlim(XLIM)
ax4.set_xlabel('Time (hrs)')
ax4.grid(False)
ax2 = plt.gca()


plt.figure(figsize=(10,5))
ax4 = plt.gca()
ax4.plot(df_sim1['t']/3600, df_sim1['R_sei1']*1000, color='k', label='Base (EC)', ls='--')
ax4.plot(df_sim1['t']/3600, df_sim1['R_sei']*1000, color='k', label='Base (EC+VC)', ls='-')
ax4.plot(df_sim2['t']/3600, df_sim2['R_sei1']*1000, color='b', ls='--', label='Fast (EC)')
ax4.plot(df_sim2['t']/3600, df_sim2['R_sei']*1000, color='b', ls='-', label='Fast (EC+VC)')
ax4.plot(df_sim3['t']/3600, df_sim3['R_sei1']*1000, color='r', ls='--', label='Fast+ (EC)')
ax4.plot(df_sim3['t']/3600, df_sim3['R_sei']*1000, color='r', ls='-', label='Fast+ (EC+VC)')
ax4.legend()
ax4.set_ylabel(r'SEI Resistance (m$\Omega$)')

ax4.set_xlim(XLIM)
ax4.set_xlabel('Time (hrs)')
ax4.grid(False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Create a table comparing SEI growth across different protocols

sim1_time1 = df_sim1['t'].iloc[-1]/3600
sim2_time1 = df_sim2['t'].iloc[-1]/3600
sim3_time1 = df_sim3['t'].iloc[-1]/3600

df_result = pd.DataFrame()

# Create column headers for different time points
time_points = ['2 hrs', 'After Formation Cycles']

protocols = []
total_sei = []
vc_pcts = []
D_sei1 = []
D_sei2 = []

 # Base formation (sim1)
for t in [2*3600, sim1_time1*3600]:
    q_sei = df_sim1[df_sim1['t'] <= t]['q_sei'].iloc[-1]
    q_sei2 = df_sim1[df_sim1['t'] <= t]['q_sei2'].iloc[-1]
    protocols.append('Base')
    total_sei.append(q_sei)
    vc_pcts.append(q_sei2/q_sei * 100)
    D_sei1.append(df_sim1[df_sim1['t'] <= t]['D_sei1'].iloc[-1])
    D_sei2.append(df_sim1[df_sim1['t'] <= t]['D_sei2'].iloc[-1])

# Fast formation (sim2)
for t in [2*3600, sim2_time1*3600]:
    q_sei = df_sim2[df_sim2['t'] <= t]['q_sei'].iloc[-1]
    q_sei2 = df_sim2[df_sim2['t'] <= t]['q_sei2'].iloc[-1]
    protocols.append('Fast')
    total_sei.append(q_sei)
    vc_pcts.append(q_sei2/q_sei * 100)
    D_sei1.append(df_sim2[df_sim2['t'] <= t]['D_sei1'].iloc[-1])
    D_sei2.append(df_sim2[df_sim2['t'] <= t]['D_sei2'].iloc[-1])

# Fast+ formation (sim3)
for t in [2*3600, sim3_time1*3600]:
    q_sei = df_sim3[df_sim3['t'] <= t]['q_sei'].iloc[-1]
    q_sei2 = df_sim3[df_sim3['t'] <= t]['q_sei2'].iloc[-1]
    protocols.append('Fast+')
    total_sei.append(q_sei)
    vc_pcts.append(q_sei2/q_sei * 100)
    D_sei1.append(df_sim3[df_sim3['t'] <= t]['D_sei1'].iloc[-1])
    D_sei2.append(df_sim3[df_sim3['t'] <= t]['D_sei2'].iloc[-1])


df_result = pd.DataFrame({
    'Protocol': protocols,
    'Time Point': time_points * 3,
    'Total SEI (Ah)': total_sei,
    'VC SEI %': vc_pcts,
    'D_sei1': D_sei1,
    'D_sei2': D_sei2
})


print(df_result.to_string(index=False))
# Out:
# Protocol             Time Point  Total SEI (Ah)  VC SEI %       D_sei1       D_sei2
#     Base                  2 hrs        0.111796 56.529709 9.582472e-20 9.582472e-20
#     Base After Formation Cycles        0.330763 21.335149 5.329907e-20 5.329907e-20
#     Fast                  2 hrs        0.166365 26.287319 5.684897e-20 5.684897e-20
#     Fast After Formation Cycles        0.266420 18.104699 5.121295e-20 5.121295e-20
#    Fast+                  2 hrs        0.183776 19.623551 5.217305e-20 5.217305e-20
#    Fast+ After Formation Cycles        0.256324 15.488003 4.963920e-20 4.963920e-20

# %% [markdown]
# # Study sensitivity of model error to choice of {DSEI1, DSEI2}
#
# Simulate protocols

# %%
nn = 10

gamma_kappa = 3367

diff_ec_vec = np.logspace(-21, -18, nn)
diff_vc_vec = np.logspace(-20, -13, nn)

rmse1_e_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse1_v_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse2_e_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse2_v_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse3_e_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse3_v_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei1_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei2_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei3_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei1_vc_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei2_vc_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei3_vc_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))

expan1_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
expan2_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
expan3_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))

resistance1_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
resistance2_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))   
resistance3_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))


for i, diff_ec in enumerate(diff_ec_vec):
    for j, diff_vc in enumerate(diff_vc_vec):

        print(f'Running simulation with D_EC = {diff_ec:.2e} m2/s and D_VC = {diff_vc:.2e} m2/s')

        try:
            df_sim1 = run_sim('base', diff_ec, diff_vc, gamma_kappa)
            df_sim2 = run_sim('fast', diff_ec, diff_vc, gamma_kappa)
            df_sim3 = run_sim('fast+', diff_ec, diff_vc, gamma_kappa)
        except:
            continue

        # Extract the qsei values:
        qsei1_mat[i, j] = df_sim1['q_sei'].iloc[-1]
        qsei2_mat[i, j] = df_sim2['q_sei'].iloc[-1]
        qsei3_mat[i, j] = df_sim3['q_sei'].iloc[-1]

        qsei1_vc_mat[i, j] = df_sim1['q_sei2'].iloc[-1]
        qsei2_vc_mat[i, j] = df_sim2['q_sei2'].iloc[-1]
        qsei3_vc_mat[i, j] = df_sim3['q_sei2'].iloc[-1]

        # Extract the expansion values:
        expan1_mat[i, j] = df_sim1['expansion'].iloc[-1]
        expan2_mat[i, j] = df_sim2['expansion'].iloc[-1]
        expan3_mat[i, j] = df_sim3['expansion'].iloc[-1]

        # Extract the resistance values:
        resistance1_mat[i, j] = df_sim1['R_sei'].iloc[-1]
        resistance2_mat[i, j] = df_sim2['R_sei'].iloc[-1]
        resistance3_mat[i, j] = df_sim3['R_sei'].iloc[-1]

        # Beware of experimental vs model data indexing!!
        rmse1_v, _, _ = calculate_rmse(expt1['arbin_time'], expt1['arbin_voltage'], df_sim1['t'], df_sim1['vt'])
        rmse1_e, _, _ = calculate_rmse(expt1['daq_time'],   expt1['daq_strain'], df_sim1['t'], df_sim1['expansion']*1e6)
        rmse2_v, _, _ = calculate_rmse(expt3['arbin_time'], expt3['arbin_voltage'], df_sim2['t'], df_sim2['vt'])
        rmse2_e, _, _ = calculate_rmse(expt3['daq_time'],   expt3['daq_strain'], df_sim2['t'], df_sim2['expansion']*1e6)
        rmse3_v, _, _ = calculate_rmse(expt4['arbin_time'], expt4['arbin_voltage'], df_sim3['t'], df_sim3['vt'])
        rmse3_e, _, _ = calculate_rmse(expt4['daq_time'],   expt4['daq_strain'], df_sim3['t'], df_sim3['expansion']*1e6)

        rmse1_e_mat[i, j] = rmse1_e
        rmse1_v_mat[i, j] = rmse1_v
        rmse2_e_mat[i, j] = rmse2_e
        rmse2_v_mat[i, j] = rmse2_v
        rmse3_e_mat[i, j] = rmse3_e
        rmse3_v_mat[i, j] = rmse3_v

# Replace zeros with np.nan in rmse1_e_mat
rmse1_e_mat = np.where(rmse1_e_mat == 0, np.nan, rmse1_e_mat)
rmse1_v_mat = np.where(rmse1_v_mat == 0, np.nan, rmse1_v_mat)
rmse2_e_mat = np.where(rmse2_e_mat == 0, np.nan, rmse2_e_mat)
rmse2_v_mat = np.where(rmse2_v_mat == 0, np.nan, rmse2_v_mat)
rmse3_e_mat = np.where(rmse3_e_mat == 0, np.nan, rmse3_e_mat)
rmse3_v_mat = np.where(rmse3_v_mat == 0, np.nan, rmse3_v_mat)
qsei1_mat = np.where(qsei1_mat == 0, np.nan, qsei1_mat)
qsei2_mat = np.where(qsei2_mat == 0, np.nan, qsei2_mat)
qsei3_mat = np.where(qsei3_mat == 0, np.nan, qsei3_mat)
qsei1_vc_mat = np.where(qsei1_vc_mat == 0, np.nan, qsei1_vc_mat)
qsei2_vc_mat = np.where(qsei2_vc_mat == 0, np.nan, qsei2_vc_mat)
qsei3_vc_mat = np.where(qsei3_vc_mat == 0, np.nan, qsei3_vc_mat)

expan1_mat = np.where(expan1_mat == 0, np.nan, expan1_mat)
expan2_mat = np.where(expan2_mat == 0, np.nan, expan2_mat)
expan3_mat = np.where(expan3_mat == 0, np.nan, expan3_mat)

resistance1_mat = np.where(resistance1_mat == 0, np.nan, resistance1_mat)
resistance2_mat = np.where(resistance2_mat == 0, np.nan, resistance2_mat)
resistance3_mat = np.where(resistance3_mat == 0, np.nan, resistance3_mat)

combined_rmse1 = rmse1_e_mat/np.nanmax(rmse1_e_mat) + rmse1_v_mat/np.nanmax(rmse1_v_mat)
combined_rmse2 = rmse2_e_mat/np.nanmax(rmse2_e_mat) + rmse2_v_mat/np.nanmax(rmse2_v_mat)
combined_rmse3 = rmse3_e_mat/np.nanmax(rmse3_e_mat) + rmse3_v_mat/np.nanmax(rmse3_v_mat)

# Compute error metrics based on cell capacity and resistance
# Rother = 0.01 + 0.001 + 0.001 # R0p + Rdiffp + Rdiffn
Rother = 0.0215 - 0.09197987391102377 # This value gets the R error to 0 for the base case
Rmeas1 = 0.0215 
Rmeas2 = 0.0178 
Rmeas3 = 0.0166 
Q_max  = 2.87
Q_meas = 2.54

# Capacity error
eq1_mat = (qsei1_mat - (Q_max - Q_meas))**2
eq2_mat = (qsei2_mat - (Q_max - Q_meas))**2
eq3_mat = (qsei3_mat - (Q_max - Q_meas))**2

# Resistance error
er1_mat = ((resistance1_mat + Rother) - Rmeas1)**2
er2_mat = ((resistance2_mat + Rother) - Rmeas2)**2
er3_mat = ((resistance3_mat + Rother) - Rmeas3)**2

# Combined capacity and resistance error
ec1_mat = (eq1_mat / np.nanmax(eq1_mat)) + (er1_mat / np.nanmax(er1_mat))
ec2_mat = (eq2_mat / np.nanmax(eq2_mat)) + (er2_mat / np.nanmax(er2_mat))
ec3_mat = (eq3_mat / np.nanmax(eq3_mat)) + (er3_mat / np.nanmax(er3_mat))
# Out:
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.00e-20 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 5.99e-20 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 3.59e-19 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 2.15e-18 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.29e-17 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 7.74e-17 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 4.64e-16 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 2.78e-15 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.67e-14 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.00e-13 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.00e-20 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 5.99e-20 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 3.59e-19 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 2.15e-18 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.29e-17 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 7.74e-17 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 4.64e-16 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 2.78e-15 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.67e-14 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.00e-13 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 1.00e-20 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# ...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 1.29e-17 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 7.74e-17 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 4.64e-16 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 2.78e-15 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 1.67e-14 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 1.00e-13 m2/s
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.0V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.0V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.0V...
# Running Cyc4: Rest for 6 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...
# Running Cyc1: Rest for 0.5 hours...
# Running Cyc2: Charge to 3.9V...
# Running Cyc2: Charge to 4.2V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc2: Discharge to 3.9V...
# Running Cyc2: Rest for 0.16666666666666666 hours...
# Running Cyc3: Charge to 4.2V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc3: Discharge to 3.9V...
# Running Cyc3: Rest for 0.16666666666666666 hours...
# Running Cyc4: Charge to 4.2V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc4: Discharge to 3.9V...
# Running Cyc4: Rest for 0.16666666666666666 hours...
# Running Cyc5: Charge to 4.2V...
# Running Cyc5: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.9V...
# Running Cyc6: Rest for 0.16666666666666666 hours...
# Running Cyc5: Discharge to 3.0V...
# Running Cyc6: Rest for 3 hours...

# %% [markdown]
# # Create a scatterplot of expansion, capacity, and resistance, for all simulated combinations of {DSEI1, DSEI2}

# %%
qsei1_flat = qsei1_mat.flatten()
qsei2_flat = qsei2_mat.flatten()
qsei3_flat = qsei3_mat.flatten()

expan1_flat = expan1_mat.flatten()
expan2_flat = expan2_mat.flatten()
expan3_flat = expan3_mat.flatten()

resistance1_flat = resistance1_mat.flatten()
resistance2_flat = resistance2_mat.flatten()
resistance3_flat = resistance3_mat.flatten()

plt.figure(figsize=(8, 6))
plt.scatter(qsei1_flat, expan1_flat*1e6, alpha=0.7, edgecolors='k', label='Base')
plt.scatter(qsei2_flat, expan2_flat*1e6, alpha=0.7, edgecolors='k', label='Fast')
plt.scatter(qsei3_flat, expan3_flat*1e6, alpha=0.7, edgecolors='k', label='Fast+')
plt.xlabel('Q_SEI (Ah)')
plt.ylabel('Expansion (um)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(qsei1_flat, resistance1_flat, alpha=0.7, edgecolors='k', label='Base')
plt.scatter(qsei2_flat, resistance2_flat, alpha=0.7, edgecolors='k', label='Fast')
plt.scatter(qsei3_flat, resistance3_flat, alpha=0.7, edgecolors='k', label='Fast+')
plt.xlabel('Q_SEI (Ah)')
plt.ylabel('Resistance (Ohms)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.ylim((0, 0.2))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Prepare data for plotting {DSEI, DSEI2} heatmaps

# %%
plot_diffusivity_heatmaps(eq1_mat, eq2_mat, eq3_mat, '$E_Q = (Q-\hat{Q})^2$', zmin=0, zmax=0.2)
plot_diffusivity_heatmaps(er1_mat, er2_mat, er3_mat, '$E_R = (R-\hat{R})^2$', zmin=0, zmax=0.01)
plot_diffusivity_heatmaps(ec1_mat, ec2_mat, ec3_mat, '$E_Q + E_R$', zmin=0.0, zmax=0.05)
plot_diffusivity_heatmaps(rmse1_v_mat, rmse2_v_mat, rmse3_v_mat, '$RMSE_{V(t)}$', zmin=0, zmax=0.5)
plot_diffusivity_heatmaps(rmse1_e_mat, rmse2_e_mat, rmse3_e_mat, '$RMSE_{\epsilon(t)}$')
plot_diffusivity_heatmaps(combined_rmse1, combined_rmse2, combined_rmse3, '$RMSE_V + RMSE_{\epsilon}$')
plot_diffusivity_heatmaps(qsei1_vc_mat, qsei2_vc_mat, qsei3_vc_mat, '$Q_{VC}$', is_error_plot=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:2: SyntaxWarning: invalid escape sequence '\h'
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:2: SyntaxWarning: invalid escape sequence '\h'
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:1: SyntaxWarning: invalid escape sequence '\h'
#   plot_diffusivity_heatmaps(eq1_mat, eq2_mat, eq3_mat, '$E_Q = (Q-\hat{Q})^2$', zmin=0, zmax=0.2)
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:2: SyntaxWarning: invalid escape sequence '\h'
#   plot_diffusivity_heatmaps(er1_mat, er2_mat, er3_mat, '$E_R = (R-\hat{R})^2$', zmin=0, zmax=0.01)
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:5: SyntaxWarning: invalid escape sequence '\e'
#   plot_diffusivity_heatmaps(rmse1_e_mat, rmse2_e_mat, rmse3_e_mat, '$RMSE_{\epsilon(t)}$')
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:6: SyntaxWarning: invalid escape sequence '\e'
#   plot_diffusivity_heatmaps(combined_rmse1, combined_rmse2, combined_rmse3, '$RMSE_V + RMSE_{\epsilon}$')
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3762856798.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis_r', 20)
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:1: SyntaxWarning: invalid escape sequence '\h'
#   plot_diffusivity_heatmaps(eq1_mat, eq2_mat, eq3_mat, '$E_Q = (Q-\hat{Q})^2$', zmin=0, zmax=0.2)
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:2: SyntaxWarning: invalid escape sequence '\h'
#   plot_diffusivity_heatmaps(er1_mat, er2_mat, er3_mat, '$E_R = (R-\hat{R})^2$', zmin=0, zmax=0.01)
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:5: SyntaxWarning: invalid escape sequence '\e'
#   plot_diffusivity_heatmaps(rmse1_e_mat, rmse2_e_mat, rmse3_e_mat, '$RMSE_{\epsilon(t)}$')
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/3871735223.py:6: SyntaxWarning: invalid escape sequence '\e'
#   plot_diffusivity_heatmaps(combined_rmse1, combined_rmse2, combined_rmse3, '$RMSE_V + RMSE_{\epsilon}$')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plot_diffusivity_heatmaps(eq1_mat, eq2_mat, eq3_mat, '$E_Q = (Q-\hat{Q})^2$', zmin=0, zmax=0.2)
#       2 plot_diffusivity_heatmaps(er1_mat, er2_mat, er3_mat, '$E_R = (R-\hat{R})^2$', zmin=0, zmax=0.01)
#       3 plot_diffusivity_heatmaps(ec1_mat, ec2_mat, ec3_mat, '$E_Q + E_R$', zmin=0.0, zmax=0.05)
#
# Cell In[4], line 27, in plot_diffusivity_heatmaps(mat1, mat2, mat3, label, is_error_plot, zmin, zmax)
#      24     cmap = cm.get_cmap('viridis_r', 20)
#      26 # Base Formation
# ---> 27     pcm1 = ax1.pcolormesh(X, Y, mat1, shading='auto', cmap=cmap)
#      28     vmin, vmax = np.nanmin(mat1), np.nanmax(mat1)
#      29     plt.colorbar(pcm1, ax=ax1, label=label, orientation='horizontal', pad=0.2)
#
# File ~/.pyenv/versions/formation-modeling-env/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/formation-modeling-env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6522, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, colorizer, shading, antialiased, *args, **kwargs)
#    6519 shading = shading.lower()
#    6520 kwargs.setdefault('edgecolors', 'none')
# -> 6522 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6523                                     shading=shading, kwargs=kwargs)
#    6524 coords = np.stack([X, Y], axis=-1)
#    6526 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File ~/.pyenv/versions/formation-modeling-env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6054, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    6052 if shading == 'flat':
#    6053     if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 6054         raise TypeError(f"Dimensions of C {C.shape} should"
#    6055                         f" be one smaller than X({Nx}) and Y({Ny})"
#    6056                         f" while using shading='flat'"
#    6057                         f" see help({funcname})")
#    6058 else:    # ['nearest', 'gouraud']:
#    6059     if (Nx, Ny) != (ncols, nrows):
#
# TypeError: Dimensions of C (10, 10) should be one smaller than X(25) and Y(25) while using shading='flat' see help(pcolormesh)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Study sensitivity of model error to choice of {DSEI1, DSEI2}
#
# Simulate measured current

# %%
nn = 10

gamma_kappa = 3367

diff_ec_vec = np.logspace(-21, -18, nn)
diff_vc_vec = np.logspace(-20, -13, nn+1)

rmse1_e_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse1_v_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse2_e_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse2_v_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse3_e_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
rmse3_v_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei1_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei2_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei3_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei1_vc_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei2_vc_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
qsei3_vc_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))

expan1_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
expan2_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
expan3_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))

resistance1_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))
resistance2_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))   
resistance3_mat = np.zeros((len(diff_ec_vec), len(diff_vc_vec)))


for i, diff_ec in enumerate(diff_ec_vec):
    for j, diff_vc in enumerate(diff_vc_vec):

        print(f'Running simulation with D_EC = {diff_ec:.2e} m2/s and D_VC = {diff_vc:.2e} m2/s')

        try:
            df_sim1 = run_sim('base', diff_ec, diff_vc, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp1)
            df_sim2 = run_sim('fast', diff_ec, diff_vc, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp3)
            df_sim3 = run_sim('fast+', diff_ec, diff_vc, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp4)
        except:
            continue

        # Extract the qsei values:
        qsei1_mat[i, j] = df_sim1['q_sei'].iloc[-1]
        qsei2_mat[i, j] = df_sim2['q_sei'].iloc[-1]
        qsei3_mat[i, j] = df_sim3['q_sei'].iloc[-1]

        qsei1_vc_mat[i, j] = df_sim1['q_sei2'].iloc[-1]
        qsei2_vc_mat[i, j] = df_sim2['q_sei2'].iloc[-1]
        qsei3_vc_mat[i, j] = df_sim3['q_sei2'].iloc[-1]

        # Extract the expansion values:
        expan1_mat[i, j] = df_sim1['expansion'].iloc[-1]
        expan2_mat[i, j] = df_sim2['expansion'].iloc[-1]
        expan3_mat[i, j] = df_sim3['expansion'].iloc[-1]

        # Extract the resistance values:
        resistance1_mat[i, j] = df_sim1['R_sei'].iloc[-1]
        resistance2_mat[i, j] = df_sim2['R_sei'].iloc[-1]
        resistance3_mat[i, j] = df_sim3['R_sei'].iloc[-1]

        # Beware of experimental vs model data indexing!!
        rmse1_v, _, _ = calculate_rmse(expt1['arbin_time'], expt1['arbin_voltage'], df_sim1['t'], df_sim1['vt'], y_range=(3.0, 4.5))
        rmse1_e, _, _ = calculate_rmse(expt1['daq_time'],   expt1['daq_strain'], df_sim1['t'], df_sim1['expansion']*1e6)
        rmse2_v, _, _ = calculate_rmse(expt3['arbin_time'], expt3['arbin_voltage'], df_sim2['t'], df_sim2['vt'], y_range=(3.0, 4.5))
        rmse2_e, _, _ = calculate_rmse(expt3['daq_time'],   expt3['daq_strain'], df_sim2['t'], df_sim2['expansion']*1e6)
        rmse3_v, _, _ = calculate_rmse(expt4['arbin_time'], expt4['arbin_voltage'], df_sim3['t'], df_sim3['vt'], y_range=(3.0, 4.5))
        rmse3_e, _, _ = calculate_rmse(expt4['daq_time'],   expt4['daq_strain'], df_sim3['t'], df_sim3['expansion']*1e6)

        rmse1_e_mat[i, j] = rmse1_e
        rmse1_v_mat[i, j] = rmse1_v
        rmse2_e_mat[i, j] = rmse2_e
        rmse2_v_mat[i, j] = rmse2_v
        rmse3_e_mat[i, j] = rmse3_e
        rmse3_v_mat[i, j] = rmse3_v

# Replace zeros with np.nan in rmse1_e_mat
rmse1_e_mat = np.where(rmse1_e_mat == 0, np.nan, rmse1_e_mat)
rmse1_v_mat = np.where(rmse1_v_mat == 0, np.nan, rmse1_v_mat)
rmse2_e_mat = np.where(rmse2_e_mat == 0, np.nan, rmse2_e_mat)
rmse2_v_mat = np.where(rmse2_v_mat == 0, np.nan, rmse2_v_mat)
rmse3_e_mat = np.where(rmse3_e_mat == 0, np.nan, rmse3_e_mat)
rmse3_v_mat = np.where(rmse3_v_mat == 0, np.nan, rmse3_v_mat)
qsei1_mat = np.where(qsei1_mat == 0, np.nan, qsei1_mat)
qsei2_mat = np.where(qsei2_mat == 0, np.nan, qsei2_mat)
qsei3_mat = np.where(qsei3_mat == 0, np.nan, qsei3_mat)
qsei1_vc_mat = np.where(qsei1_vc_mat == 0, np.nan, qsei1_vc_mat)
qsei2_vc_mat = np.where(qsei2_vc_mat == 0, np.nan, qsei2_vc_mat)
qsei3_vc_mat = np.where(qsei3_vc_mat == 0, np.nan, qsei3_vc_mat)

expan1_mat = np.where(expan1_mat == 0, np.nan, expan1_mat)
expan2_mat = np.where(expan2_mat == 0, np.nan, expan2_mat)
expan3_mat = np.where(expan3_mat == 0, np.nan, expan3_mat)

resistance1_mat = np.where(resistance1_mat == 0, np.nan, resistance1_mat)
resistance2_mat = np.where(resistance2_mat == 0, np.nan, resistance2_mat)
resistance3_mat = np.where(resistance3_mat == 0, np.nan, resistance3_mat)

combined_rmse1 = rmse1_e_mat/np.nanmax(rmse1_e_mat) + rmse1_v_mat/np.nanmax(rmse1_v_mat)
combined_rmse2 = rmse2_e_mat/np.nanmax(rmse2_e_mat) + rmse2_v_mat/np.nanmax(rmse2_v_mat)
combined_rmse3 = rmse3_e_mat/np.nanmax(rmse3_e_mat) + rmse3_v_mat/np.nanmax(rmse3_v_mat)

# Compute error metrics based on cell capacity and resistance
# Rother = 0.01 + 0.001 + 0.001 # R0p + Rdiffp + Rdiffn
Rother = 0.0215 - 0.09197987391102377 # This value gets the R error to 0 for the base case
Rmeas1 = 0.0215 
Rmeas2 = 0.0178 
Rmeas3 = 0.0166 
Q_max  = 2.87
Q_meas = 2.54

# Capacity error
eq1_mat = (qsei1_mat - (Q_max - Q_meas))**2
eq2_mat = (qsei2_mat - (Q_max - Q_meas))**2
eq3_mat = (qsei3_mat - (Q_max - Q_meas))**2

# Resistance error
er1_mat = ((resistance1_mat + Rother) - Rmeas1)**2
er2_mat = ((resistance2_mat + Rother) - Rmeas2)**2
er3_mat = ((resistance3_mat + Rother) - Rmeas3)**2

# Combined capacity and resistance error
ec1_mat = (eq1_mat / np.nanmax(eq1_mat)) + (er1_mat / np.nanmax(er1_mat))
ec2_mat = (eq2_mat / np.nanmax(eq2_mat)) + (er2_mat / np.nanmax(er2_mat))
ec3_mat = (eq3_mat / np.nanmax(eq3_mat)) + (er3_mat / np.nanmax(er3_mat))
# Out:
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 5.01e-20 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 1.00e-21 m2/s and D_VC = 1.00e-13 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 5.01e-20 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 2.15e-21 m2/s and D_VC = 1.00e-13 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 5.01e-20 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 4.64e-21 m2/s and D_VC = 1.00e-13 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 5.01e-20 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 1.00e-20 m2/s and D_VC = 1.00e-13 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 5.01e-20 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 2.15e-20 m2/s and D_VC = 1.00e-13 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 5.01e-20 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 7.94e-16 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 3.98e-15 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 2.00e-14 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 4.64e-20 m2/s and D_VC = 1.00e-13 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 5.01e-20 m2/s
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 1.26e-18 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 6.31e-18 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 3.16e-17 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 1.58e-16 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 7.94e-16 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 3.98e-15 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 2.00e-14 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-19 m2/s and D_VC = 1.00e-13 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 5.01e-20 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 2.51e-19 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 1.26e-18 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 6.31e-18 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 2.15e-19 m2/s and D_VC = 1.00e-13 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 1.00e-20 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 5.01e-20 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 4.64e-19 m2/s and D_VC = 1.00e-13 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 1.00e-20 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 5.01e-20 m2/s
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 2.51e-19 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 1.26e-18 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 6.31e-18 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 3.16e-17 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 1.58e-16 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 7.94e-16 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 3.98e-15 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 2.00e-14 m2/s
# Running simulation with D_EC = 1.00e-18 m2/s and D_VC = 1.00e-13 m2/s

# %%
plot_diffusivity_heatmaps(diff_ec_vec, diff_vc_vec, rmse1_v_mat, rmse2_v_mat, rmse3_v_mat, '$RMSE_{V(t)}$', zmin=0, zmax=0.15)
plot_diffusivity_heatmaps(diff_ec_vec, diff_vc_vec, rmse1_e_mat, rmse2_e_mat, rmse3_e_mat, '$RMSE_{\epsilon(t)}$')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\e'
# <>:2: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/2316770137.py:2: SyntaxWarning: invalid escape sequence '\e'
#   plot_diffusivity_heatmaps(diff_ec_vec, diff_vc_vec, rmse1_e_mat, rmse2_e_mat, rmse3_e_mat, '$RMSE_{\epsilon(t)}$')
# /var/folders/33/qps6sqvx73v5zk2zp2wxxgpm0000gn/T/ipykernel_51694/1277975092.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis_r', 20)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Re-run the simulations using optimal Dsei

# %%
# d_ec_opt = 2.84e-20
# d_vc_opt = 5.39e-14
gamma_kappa = 3367

d_vc_opt = 6.14664e-14
d_ec_opt = 4.5185e-20

df_sim1 = run_sim('base', d_ec_opt, d_vc_opt, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp1)
df_sim2 = run_sim('fast', d_ec_opt, d_vc_opt, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp3)
df_sim3 = run_sim('fast+', d_ec_opt, d_vc_opt, gamma_kappa, dt=dt_data_interp, to_follow_current=True, current_vec=i_interp4)

XLIM = (0, 30)

rmse1_v, _, _ = calculate_rmse(expt1['arbin_time'], expt1['arbin_voltage'], df_sim1['t'], df_sim1['vt'])
rmse1_e, _, _ = calculate_rmse(expt1['daq_time'],   expt1['daq_strain'], df_sim1['t'], df_sim1['expansion']*1e6)
rmse2_v, _, _ = calculate_rmse(expt3['arbin_time'], expt3['arbin_voltage'], df_sim2['t'], df_sim2['vt'])
rmse2_e, _, _ = calculate_rmse(expt3['daq_time'],   expt3['daq_strain'], df_sim2['t'], df_sim2['expansion']*1e6)
rmse3_v, _, _ = calculate_rmse(expt4['arbin_time'], expt4['arbin_voltage'], df_sim3['t'], df_sim3['vt'])
rmse3_e, _, _ = calculate_rmse(expt4['daq_time'],   expt4['daq_strain'], df_sim3['t'], df_sim3['expansion']*1e6)

# The voltage plot
plt.figure(figsize=(10,5))
ax = plt.gca()
ax.plot(expt1['arbin_time']/3600, expt1['arbin_voltage'], color='k', label=f'Base, RMSE = {rmse1_v:.2f} V, D_EC = {d_ec_opt:.2e} m2/s, D_VC = {d_vc_opt:.2e} m2/s')
ax.plot(expt3['arbin_time']/3600, expt3['arbin_voltage'], color='b', label=f'Fast, RMSE = {rmse2_v:.2f} V, D_EC = {d_ec_opt:.2e} m2/s, D_VC = {d_vc_opt:.2e} m2/s')
ax.plot(expt4['arbin_time']/3600, expt4['arbin_voltage'], color='r', label=f'Fast+, RMSE = {rmse3_v:.2f} V, D_EC = {d_ec_opt:.2e} m2/s, D_VC = {d_vc_opt:.2e} m2/s')
ax.plot(df_sim1['t']/3600, df_sim1['vt'], color='k', ls='--', label='')
ax.plot(df_sim2['t']/3600, df_sim2['vt'], color='b', ls='--', label='')
ax.plot(df_sim3['t']/3600, df_sim3['vt'], color='r', ls='--', label='')
ax.set_xlabel('Time (hrs)')
ax.set_ylabel('Voltage (V)')
ax.set_ylim(bottom=0)
ax.set_xlim(XLIM)
ax.legend(fontsize=12)
ax.grid(False)

# The expansion plot
plt.figure(figsize=(10,5))
ax = plt.gca()
ax.plot(expt1['daq_time']/3600, expt1['daq_strain'], color='k', label=f'Base, RMSE = {rmse1_e:.2f} um')
ax.plot(expt3['daq_time']/3600, expt3['daq_strain'], color='b', label=f'Fast, RMSE = {rmse2_e:.2f} um')
ax.plot(expt4['daq_time']/3600, expt4['daq_strain'], color='r', label=f'Fast+, RMSE = {rmse3_e:.2f} um')
ax.plot(df_sim1['t']/3600, (df_sim1['expansion'])*1e6, color='k', ls='--', label='')
ax.plot(df_sim2['t']/3600, (df_sim2['expansion'])*1e6, color='b', ls='--', label='')
ax.plot(df_sim3['t']/3600, (df_sim3['expansion'])*1e6, color='r', ls='--', label='')
ax.legend(fontsize=12)
ax.set_ylabel(r'Expansion ($\mu$m)')
ax.set_ylim(bottom=0, top=150)
ax.set_xlabel('Time (hrs)')
ax.set_xlim(XLIM)
ax.grid(False)

# The current plot
plt.figure(figsize=(10,5))
ax = plt.gca()
ax.plot(expt1['arbin_time']/3600, expt1['arbin_current'], color='k', label='Base')
ax.plot(expt3['arbin_time']/3600, expt3['arbin_current'], color='b', label='Fast')
ax.plot(expt4['arbin_time']/3600, expt4['arbin_current'], color='r', label='Fast+')
ax.plot(df_sim1['t']/3600, df_sim1['i_app'], color='k', ls='--', label='')
ax.plot(df_sim2['t']/3600, df_sim2['i_app'], color='b', ls='--', label='')
ax.plot(df_sim3['t']/3600, df_sim3['i_app'], color='r', ls='--', label='')
ax.set_xlabel('Time (hrs)')
ax.set_ylabel('Current (A)')
ax.legend(fontsize=12)
ax.grid(False)
ax.set_xlim(XLIM)
# Out:
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: overflow encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:274: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei1[k+1] = 1 / (1/self.j_sei_rxn1[k+1] + 1/self.j_sei_dif1[k+1])
# /Users/ampere/code/formation-modeling/src/cellsim.py:275: RuntimeWarning: divide by zero encountered in scalar divide
#   self.j_sei2[k+1] = 1 / (1/self.j_sei_rxn2[k+1] + 1/self.j_sei_dif2[k+1])
# (0.0, 30.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
